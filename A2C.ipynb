# %%
import random, numpy as np, torch, torch.nn as nn, torch.nn.functional as F
import ale_py   
import gymnasium as gym
from gymnasium.wrappers import AtariPreprocessing, FrameStack
from torch.distributions import Categorical
from collections import deque

# %%
# ──────────────────────────────────────────────────────────────────────────
# 1. Hyper-parameters & configuration
# ──────────────────────────────────────────────────────────────────────────
class Config:
    # Environment
    env_id: str = "ALE/MsPacman-v5"
    seed: int = 42
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # A2C
    epsilon: float = 0.05
    gamma: float = 0.99
    rollout_steps: int = 5
    total_episodes: int = 10_000

    # Optimisation
    lr: float = 1e-4
    entropy_coef: float = 0.05
    value_loss_coef: float = 0.5        
    grad_clip_norm: float = 0.5         

    # Logging
    log_interval: int = 1             
    moving_avg_episodes: int = 100

    # DEBUG 
    debug_interval: int = 10
    

# Reproducibility
random.seed(Config.seed)
np.random.seed(Config.seed)
torch.manual_seed(Config.seed)
if Config.device.type == "cuda":
    torch.cuda.manual_seed_all(Config.seed)

# %%
# ──────────────────────────────────────────────────────────────────────────
# 2. Helpers – environment factory
# ──────────────────────────────────────────────────────────────────────────
def make_env(env_id: str, seed: int | None = None) -> gym.Env:
    env = gym.make(
        env_id,
        frameskip=1,
        full_action_space=False
    )
    env = AtariPreprocessing(
        env,
        frame_skip=4,
        screen_size=84,
        terminal_on_life_loss=False,
        grayscale_obs=True,
        scale_obs=True
    )
    env = FrameStack(env, num_stack=4)
    if seed is not None:
        env.reset(seed=seed)
        env.action_space.seed(seed)
    return env

# %%
# ──────────────────────────────────────────────────────────────────────────
# 3. Neural network – shared conv base + policy/value heads
# ──────────────────────────────────────────────────────────────────────────
class ActorCriticNet(nn.Module):
    def __init__(self, input_shape: tuple[int, int, int], num_actions: int):
        super().__init__()

        # In FrameStack the shape is (C,H,W) where C ≤ 4
        if len(input_shape) != 3:
            raise ValueError("Expected 3-D input shape") 
        channels, height, width = input_shape if input_shape[0] <= 4 else (input_shape[2], *input_shape[:2])

        self.conv1 = nn.Conv2d(channels, 32, 8, 4)
        self.conv2 = nn.Conv2d(32, 64, 4, 2)
        self.conv3 = nn.Conv2d(64, 64, 3, 1)

        # Compute conv output size
        with torch.no_grad():
            dummy = torch.zeros(1, channels, height, width)
            out = self._forward_conv(dummy)
            flat = out.view(1, -1).size(1)

        self.fc = nn.Linear(flat, 1024)
        self.policy_head = nn.Linear(1024, num_actions)
        self.value_head = nn.Linear(1024, 1)

    def _forward_conv(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        return x

    def forward(self, x):
        # convert to float and channels-first
        x = x.float()
        if x.ndim == 4 and x.shape[1] not in (1, 3, 4):
            # channels last -- channels first
            x = x.permute(0, 3, 1, 2)
        if x.max() > 1.0:
            x = x / 255.0
        x = self._forward_conv(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc(x))
        logits = self.policy_head(x)
        value = self.value_head(x)
        return logits, value.squeeze(-1)

# %%
# ──────────────────────────────────────────────────────────────────────────
# 4. A2C agent
# ──────────────────────────────────────────────────────────────────────────
class A2CAgent:
    def __init__(self, model: nn.Module, cfg: Config):
        self.model = model
        self.device = cfg.device
        self.gamma = cfg.gamma
        self.entropy_coef = cfg.entropy_coef
        self.optimizer = torch.optim.Adam(model.parameters(), lr=cfg.lr)

    def select_action(self, state):
        state_t = torch.tensor(state, device=self.device)
        if state_t.ndim == 3:
            state_t = state_t.unsqueeze(0)
        logits, value = self.model(state_t)
        dist = Categorical(logits=logits)
        action = dist.sample()
        if random.random() < Config.epsilon:
            action = torch.tensor(dist.sample().new_full((), random.randrange(dist.probs.size(-1))))
        return (
            action.item(),
            dist.log_prob(action).squeeze(0),
            value.squeeze(0),
            dist.entropy().squeeze(0)
        )

    def update(self, rewards, log_probs, values, entropies, next_value, done):
        """Performs the A2C update and returns debug scalars."""
        rewards = torch.tensor(rewards, device=self.device, dtype=torch.float32)
        log_probs = torch.stack(log_probs)
        values = torch.stack(values)
        entropies = torch.stack(entropies)

        # Compute returns
        R = 0.0 if done else next_value.item()
        returns = []
        for r in reversed(rewards):
            R = r + self.gamma * R
            returns.insert(0, R)
        returns = torch.tensor(returns, device=self.device)

        advantages = returns - values.detach()
        adv_mean = advantages.mean()
        adv_std  = advantages.std(unbiased=False)        # never NaN for 1 element
        advantages = (advantages - adv_mean) / (adv_std + 1e-8)

        # Losses
        policy_loss = -(advantages * log_probs).mean()
        value_loss = F.mse_loss(values, returns)
        entropy_mean = entropies.mean()
        total_loss = (policy_loss
              + Config.value_loss_coef * value_loss
              - Config.entropy_coef      * entropies.mean())

        # Back-prop
        self.optimizer.zero_grad()
        total_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), Config.grad_clip_norm)
        self.optimizer.step()

        # DEBUG scalars (Python floats)
        return (
            policy_loss.item(),
            value_loss.item(),
            entropy_mean.item(),
            total_loss.item(),
            advantages.mean().item(),
            advantages.min().item(),
            advantages.max().item()
        )

# %%
# ──────────────────────────────────────────────────────────────────────────
# 5. Training loop with integrated debugging
# ──────────────────────────────────────────────────────────────────────────
def main():
    env = make_env(Config.env_id, Config.seed)
    obs_shape = env.observation_space.shape      # (C, H, W) after preprocessing
    n_actions = env.action_space.n

    model = ActorCriticNet(obs_shape, n_actions).to(Config.device)
    agent = A2CAgent(model, Config)

    episode_rewards = deque(maxlen=Config.moving_avg_episodes)

    # DEBUG accumulators
    debug_on = bool(Config.debug_interval)
    interval = Config.debug_interval or 1  # avoid div by zero

    act_counts_interval = np.zeros(n_actions, dtype=int)
    pl_sum = vl_sum = ent_sum = tot_sum = adv_mean_sum = 0.0
    adv_min_list, adv_max_list = [], []

    for ep in range(1, Config.total_episodes + 1):
        state, _ = env.reset()
        done, total_reward = False, 0.0
        # Per-episode action counts (for optional per-episode analysis)
        ep_act_counts = np.zeros(n_actions, dtype=int)

        # Roll out until done
        while not done:
            rewards, log_probs, values, entropies = [], [], [], []

            # n-step rollout (or until episode ends)
            for _ in range(Config.rollout_steps):
                action, logprob, value, entropy = agent.select_action(state)
                next_state, reward, terminated, truncated, _ = env.step(action)
                done = terminated or truncated

                rewards.append(reward)
                log_probs.append(logprob)
                values.append(value)
                entropies.append(entropy)
                total_reward += reward
                ep_act_counts[action] += 1

                state = next_state
                if done:
                    break

            # bootstrap value
            if done:
                next_val = torch.zeros(1, device=Config.device)
            else:
                st_t = torch.tensor(state, device=Config.device)
                if st_t.ndim == 3:
                    st_t = st_t.unsqueeze(0)
                with torch.no_grad():
                    _, next_val_t = agent.model(st_t)
                next_val = next_val_t.squeeze(0)

            # agent update & debug scalars
            pl, vl, ent, tot, adv_m, adv_min, adv_max = agent.update(
                rewards, log_probs, values, entropies, next_val, done
            )

        # ─── end of episode ────────────────────────────────────────────
        episode_rewards.append(total_reward)

        # accumulate debug stats
        if debug_on:
            pl_sum += pl
            vl_sum += vl
            ent_sum += ent
            tot_sum += tot
            adv_mean_sum += adv_m
            adv_min_list.append(adv_min)
            adv_max_list.append(adv_max)
            act_counts_interval += ep_act_counts

        # reward log
        if ep % Config.log_interval == 0:
            avg_r = sum(episode_rewards) / len(episode_rewards)
            print(f"Episode {ep:<4d} | EpReward: {total_reward:>6.2f} | MovingAvg({len(episode_rewards)}): {avg_r:6.2f}")

        # DEBUG print every N episodes
        if debug_on and ep % interval == 0:
            avg_pl  = pl_sum  / interval
            avg_vl  = vl_sum  / interval
            avg_ent = ent_sum / interval
            avg_tot = tot_sum / interval
            avg_adv_mean = adv_mean_sum / interval
            adv_min_int = min(adv_min_list)
            adv_max_int = max(adv_max_list)

            total_act = act_counts_interval.sum()
            if total_act:
                pct = act_counts_interval / total_act * 100.0
                act_dist = ", ".join(f"{i}:{c} ({p:.1f}%)" for i, (c, p) in enumerate(zip(act_counts_interval, pct)))
            else:
                act_dist = "n/a"

            print(f"\n--- DEBUG {ep - interval + 1}-{ep} ---")
            print(f"Avg PolicyLoss: {avg_pl:.4f} | Avg ValueLoss: {avg_vl:.4f} | "
                  f"Avg Entropy: {avg_ent:.4f} | Avg TotalLoss: {avg_tot:.4f}")
            print(f"Advantage μ: {avg_adv_mean:.4f} | min: {adv_min_int:.4f} | max: {adv_max_int:.4f}")
            print(f"Action distribution (last {interval} eps): {act_dist}\n")

            # reset accumulators
            pl_sum = vl_sum = ent_sum = tot_sum = adv_mean_sum = 0.0
            adv_min_list.clear()
            adv_max_list.clear()
            act_counts_interval.fill(0)

    # closing the environment
    env.close()

# %%
# ──────────────────────────────────────────────────────────────────────────
# 6. Execution
# ──────────────────────────────────────────────────────────────────────────
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:596: UserWarning: WARN: plugin: shimmy.registration:register_gymnasium_envs raised Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py", line 594, in load_plugin_envs
#     fn()
#   File "/usr/local/lib/python3.11/dist-packages/shimmy/registration.py", line 304, in register_gymnasium_envs
#     _register_atari_envs()
#   File "/usr/local/lib/python3.11/dist-packages/shimmy/registration.py", line 205, in _register_atari_envs
#     import ale_py
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/__init__.py", line 68, in <module>
#     register_v0_v4_envs()
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/registration.py", line 178, in register_v0_v4_envs
#     _register_rom_configs(legacy_games, obs_types, versions)
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/registration.py", line 63, in _register_rom_configs
#     gymnasium.register(
#     ^^^^^^^^^^^^^^^^^^
# AttributeError: partially initialized module 'gymnasium' has no attribute 'register' (most likely due to a circular import)
#
#   logger.warn(f"plugin: {plugin.value} raised {traceback.format_exc()}")
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# /tmp/ipykernel_31/1070633479.py:127: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   state_t = torch.tensor(state, device=self.device)
# /tmp/ipykernel_31/1070633479.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   action = torch.tensor(dist.sample().new_full((), random.randrange(dist.probs.size(-1))))
# Episode 1    | EpReward: 250.00 | MovingAvg(1): 250.00
# Episode 2    | EpReward: 440.00 | MovingAvg(2): 345.00
# Episode 3    | EpReward: 270.00 | MovingAvg(3): 320.00
# Episode 4    | EpReward: 160.00 | MovingAvg(4): 280.00
# Episode 5    | EpReward: 390.00 | MovingAvg(5): 302.00
# Episode 6    | EpReward: 130.00 | MovingAvg(6): 273.33
# Episode 7    | EpReward: 230.00 | MovingAvg(7): 267.14
# Episode 8    | EpReward: 240.00 | MovingAvg(8): 263.75
# Episode 9    | EpReward: 240.00 | MovingAvg(9): 261.11
# Episode 10   | EpReward: 540.00 | MovingAvg(10): 289.00
#
# --- DEBUG 1-10 ---
# Avg PolicyLoss: -0.2102 | Avg ValueLoss: 4.6368 | Avg Entropy: 1.6788 | Avg TotalLoss: 2.0243
# Advantage μ: 0.0000 | min: -1.5681 | max: 1.8324
# Action distribution (last 10 eps): 0:1825 (34.2%), 1:405 (7.6%), 2:431 (8.1%), 3:154 (2.9%), 4:197 (3.7%), 5:432 (8.1%), 6:332 (6.2%), 7:622 (11.7%), 8:939 (17.6%)
#
# Episode 11   | EpReward: 760.00 | MovingAvg(11): 331.82
# Episode 12   | EpReward: 160.00 | MovingAvg(12): 317.50
# Episode 13   | EpReward: 280.00 | MovingAvg(13): 314.62
# Episode 14   | EpReward: 240.00 | MovingAvg(14): 309.29
# Episode 15   | EpReward: 190.00 | MovingAvg(15): 301.33
# Episode 16   | EpReward: 260.00 | MovingAvg(16): 298.75
# Episode 17   | EpReward: 510.00 | MovingAvg(17): 311.18
# Episode 18   | EpReward: 400.00 | MovingAvg(18): 316.11
# Episode 19   | EpReward: 170.00 | MovingAvg(19): 308.42
# Episode 20   | EpReward: 450.00 | MovingAvg(20): 315.50
#
# --- DEBUG 11-20 ---
# Avg PolicyLoss: -0.0123 | Avg ValueLoss: 3.4183 | Avg Entropy: 1.8130 | Avg TotalLoss: 1.6062
# Advantage μ: -0.0011 | min: -1.4839 | max: 1.6673
# Action distribution (last 10 eps): 0:559 (10.0%), 1:970 (17.3%), 2:286 (5.1%), 3:155 (2.8%), 4:181 (3.2%), 5:432 (7.7%), 6:407 (7.2%), 7:378 (6.7%), 8:2246 (40.0%)
#
# Episode 21   | EpReward: 170.00 | MovingAvg(21): 308.57
# Episode 22   | EpReward: 190.00 | MovingAvg(22): 303.18
# Episode 23   | EpReward: 180.00 | MovingAvg(23): 297.83
# Episode 24   | EpReward: 130.00 | MovingAvg(24): 290.83
# Episode 25   | EpReward: 190.00 | MovingAvg(25): 286.80
# Episode 26   | EpReward: 250.00 | MovingAvg(26): 285.38
# Episode 27   | EpReward: 230.00 | MovingAvg(27): 283.33
# Episode 28   | EpReward: 500.00 | MovingAvg(28): 291.07
# Episode 29   | EpReward: 100.00 | MovingAvg(29): 284.48
# Episode 30   | EpReward: 150.00 | MovingAvg(30): 280.00
#
# --- DEBUG 21-30 ---
# Avg PolicyLoss: -0.1137 | Avg ValueLoss: 2.5929 | Avg Entropy: 1.9426 | Avg TotalLoss: 1.0856
# Advantage μ: 0.0001 | min: -1.7121 | max: 1.5824
# Action distribution (last 10 eps): 0:542 (12.5%), 1:1014 (23.4%), 2:242 (5.6%), 3:129 (3.0%), 4:164 (3.8%), 5:353 (8.2%), 6:442 (10.2%), 7:310 (7.2%), 8:1135 (26.2%)
#
# Episode 31   | EpReward: 130.00 | MovingAvg(31): 275.16
# Episode 32   | EpReward: 270.00 | MovingAvg(32): 275.00
# Episode 33   | EpReward: 890.00 | MovingAvg(33): 293.64
# Episode 34   | EpReward: 640.00 | MovingAvg(34): 303.82
# Episode 35   | EpReward: 130.00 | MovingAvg(35): 298.86
# Episode 36   | EpReward: 1860.00 | MovingAvg(36): 342.22
# Episode 37   | EpReward: 530.00 | MovingAvg(37): 347.30
# Episode 38   | EpReward: 540.00 | MovingAvg(38): 352.37
# Episode 39   | EpReward: 640.00 | MovingAvg(39): 359.74
# Episode 40   | EpReward: 230.00 | MovingAvg(40): 356.50
#
# --- DEBUG 31-40 ---
# Avg PolicyLoss: 0.2435 | Avg ValueLoss: 4.8141 | Avg Entropy: 1.7768 | Avg TotalLoss: 2.5617
# Advantage μ: 0.0001 | min: -1.3999 | max: 1.5453
# Action distribution (last 10 eps): 0:506 (9.0%), 1:1436 (25.7%), 2:208 (3.7%), 3:105 (1.9%), 4:221 (4.0%), 5:462 (8.3%), 6:537 (9.6%), 7:300 (5.4%), 8:1818 (32.5%)
#
# Episode 41   | EpReward: 290.00 | MovingAvg(41): 354.88
# Episode 42   | EpReward: 230.00 | MovingAvg(42): 351.90
# Episode 43   | EpReward: 180.00 | MovingAvg(43): 347.91
# Episode 44   | EpReward: 200.00 | MovingAvg(44): 344.55
# Episode 45   | EpReward: 140.00 | MovingAvg(45): 340.00
# Episode 46   | EpReward: 350.00 | MovingAvg(46): 340.22
# Episode 47   | EpReward: 220.00 | MovingAvg(47): 337.66
# Episode 48   | EpReward: 290.00 | MovingAvg(48): 336.67
# Episode 49   | EpReward: 280.00 | MovingAvg(49): 335.51
# Episode 50   | EpReward: 550.00 | MovingAvg(50): 339.80
#
# --- DEBUG 41-50 ---
# Avg PolicyLoss: -0.2256 | Avg ValueLoss: 7.2996 | Avg Entropy: 1.7121 | Avg TotalLoss: 3.3386
# Advantage μ: 0.0002 | min: -1.9025 | max: 1.9618
# Action distribution (last 10 eps): 0:348 (7.2%), 1:572 (11.9%), 2:243 (5.1%), 3:95 (2.0%), 4:203 (4.2%), 5:1784 (37.1%), 6:531 (11.1%), 7:197 (4.1%), 8:830 (17.3%)
#
# Episode 51   | EpReward: 240.00 | MovingAvg(51): 337.84
# Episode 52   | EpReward: 320.00 | MovingAvg(52): 337.50
# Episode 53   | EpReward: 970.00 | MovingAvg(53): 349.43
# Episode 54   | EpReward: 150.00 | MovingAvg(54): 345.74
# Episode 55   | EpReward: 610.00 | MovingAvg(55): 350.55
# Episode 56   | EpReward: 230.00 | MovingAvg(56): 348.39
# Episode 57   | EpReward: 240.00 | MovingAvg(57): 346.49
# Episode 58   | EpReward: 220.00 | MovingAvg(58): 344.31
# Episode 59   | EpReward: 260.00 | MovingAvg(59): 342.88
# Episode 60   | EpReward: 540.00 | MovingAvg(60): 346.17
#
# --- DEBUG 51-60 ---
# Avg PolicyLoss: 0.0480 | Avg ValueLoss: 4.3856 | Avg Entropy: 1.9021 | Avg TotalLoss: 2.1457
# Advantage μ: -0.0000 | min: -1.6547 | max: 1.3973
# Action distribution (last 10 eps): 0:504 (9.8%), 1:784 (15.3%), 2:241 (4.7%), 3:121 (2.4%), 4:217 (4.2%), 5:1821 (35.5%), 6:552 (10.8%), 7:287 (5.6%), 8:607 (11.8%)
#
# Episode 61   | EpReward:  70.00 | MovingAvg(61): 341.64
# Episode 62   | EpReward: 170.00 | MovingAvg(62): 338.87
# Episode 63   | EpReward: 320.00 | MovingAvg(63): 338.57
# Episode 64   | EpReward: 280.00 | MovingAvg(64): 337.66
# Episode 65   | EpReward: 210.00 | MovingAvg(65): 335.69
# Episode 66   | EpReward: 210.00 | MovingAvg(66): 333.79
# Episode 67   | EpReward: 260.00 | MovingAvg(67): 332.69
# Episode 68   | EpReward: 190.00 | MovingAvg(68): 330.59
# Episode 69   | EpReward: 640.00 | MovingAvg(69): 335.07
# Episode 70   | EpReward: 550.00 | MovingAvg(70): 338.14
#
# --- DEBUG 61-70 ---
# Avg PolicyLoss: 0.0948 | Avg ValueLoss: 4.9534 | Avg Entropy: 1.9535 | Avg TotalLoss: 2.4739
# Advantage μ: 0.0001 | min: -1.6925 | max: 1.8875
# Action distribution (last 10 eps): 0:548 (10.6%), 1:865 (16.8%), 2:305 (5.9%), 3:104 (2.0%), 4:265 (5.1%), 5:1487 (28.8%), 6:701 (13.6%), 7:262 (5.1%), 8:618 (12.0%)
#
# Episode 71   | EpReward: 100.00 | MovingAvg(71): 334.79
# Episode 72   | EpReward: 190.00 | MovingAvg(72): 332.78
# Episode 73   | EpReward: 220.00 | MovingAvg(73): 331.23
# Episode 74   | EpReward: 200.00 | MovingAvg(74): 329.46
# Episode 75   | EpReward: 220.00 | MovingAvg(75): 328.00
# Episode 76   | EpReward: 160.00 | MovingAvg(76): 325.79
# Episode 77   | EpReward: 250.00 | MovingAvg(77): 324.81
# Episode 78   | EpReward: 260.00 | MovingAvg(78): 323.97
# Episode 79   | EpReward: 160.00 | MovingAvg(79): 321.90
# Episode 80   | EpReward: 750.00 | MovingAvg(80): 327.25
#
# --- DEBUG 71-80 ---
# Avg PolicyLoss: 0.0398 | Avg ValueLoss: 5.0457 | Avg Entropy: 1.9595 | Avg TotalLoss: 2.4647
# Advantage μ: 0.0000 | min: -1.9816 | max: 1.4625
# Action distribution (last 10 eps): 0:610 (14.1%), 1:638 (14.8%), 2:311 (7.2%), 3:126 (2.9%), 4:214 (5.0%), 5:1210 (28.0%), 6:456 (10.6%), 7:350 (8.1%), 8:402 (9.3%)
#
# Episode 81   | EpReward: 270.00 | MovingAvg(81): 326.54
# Episode 82   | EpReward: 310.00 | MovingAvg(82): 326.34
# Episode 83   | EpReward: 260.00 | MovingAvg(83): 325.54
# Episode 84   | EpReward: 380.00 | MovingAvg(84): 326.19
# Episode 85   | EpReward: 150.00 | MovingAvg(85): 324.12
# Episode 86   | EpReward: 230.00 | MovingAvg(86): 323.02
# Episode 87   | EpReward: 630.00 | MovingAvg(87): 326.55
# Episode 88   | EpReward: 130.00 | MovingAvg(88): 324.32
# Episode 89   | EpReward: 270.00 | MovingAvg(89): 323.71
# Episode 90   | EpReward: 150.00 | MovingAvg(90): 321.78
#
# --- DEBUG 81-90 ---
# Avg PolicyLoss: 0.0300 | Avg ValueLoss: 4.6726 | Avg Entropy: 1.9756 | Avg TotalLoss: 2.2675
# Advantage μ: 0.0001 | min: -1.4804 | max: 1.5885
# Action distribution (last 10 eps): 0:649 (14.1%), 1:698 (15.2%), 2:235 (5.1%), 3:96 (2.1%), 4:178 (3.9%), 5:1384 (30.0%), 6:474 (10.3%), 7:425 (9.2%), 8:467 (10.1%)
#
# Episode 91   | EpReward: 310.00 | MovingAvg(91): 321.65
# Episode 92   | EpReward: 190.00 | MovingAvg(92): 320.22
# Episode 93   | EpReward: 170.00 | MovingAvg(93): 318.60
# Episode 94   | EpReward: 130.00 | MovingAvg(94): 316.60
# Episode 95   | EpReward: 330.00 | MovingAvg(95): 316.74
# Episode 96   | EpReward: 230.00 | MovingAvg(96): 315.83
# Episode 97   | EpReward: 260.00 | MovingAvg(97): 315.26
# Episode 98   | EpReward: 250.00 | MovingAvg(98): 314.59
# Episode 99   | EpReward: 230.00 | MovingAvg(99): 313.74
# Episode 100  | EpReward: 200.00 | MovingAvg(100): 312.60
#
# --- DEBUG 91-100 ---
# Avg PolicyLoss: 0.0991 | Avg ValueLoss: 3.1593 | Avg Entropy: 2.0915 | Avg TotalLoss: 1.5741
# Advantage μ: -0.0000 | min: -1.8833 | max: 1.6112
# Action distribution (last 10 eps): 0:583 (13.0%), 1:469 (10.5%), 2:358 (8.0%), 3:212 (4.7%), 4:231 (5.2%), 5:1072 (23.9%), 6:340 (7.6%), 7:502 (11.2%), 8:714 (15.9%)
#
# Episode 101  | EpReward: 330.00 | MovingAvg(100): 313.40
# Episode 102  | EpReward: 230.00 | MovingAvg(100): 311.30
# Episode 103  | EpReward: 260.00 | MovingAvg(100): 311.20
# Episode 104  | EpReward: 590.00 | MovingAvg(100): 315.50
# Episode 105  | EpReward: 490.00 | MovingAvg(100): 316.50
# Episode 106  | EpReward: 990.00 | MovingAvg(100): 325.10
# Episode 107  | EpReward: 930.00 | MovingAvg(100): 332.10
# Episode 108  | EpReward: 510.00 | MovingAvg(100): 334.80
# Episode 109  | EpReward: 840.00 | MovingAvg(100): 340.80
# Episode 110  | EpReward: 510.00 | MovingAvg(100): 340.50
#
# --- DEBUG 101-110 ---
# Avg PolicyLoss: -0.1133 | Avg ValueLoss: 16.5283 | Avg Entropy: 2.0117 | Avg TotalLoss: 8.0503
# Advantage μ: 0.0001 | min: -1.9163 | max: 1.4276
# Action distribution (last 10 eps): 0:721 (12.6%), 1:523 (9.1%), 2:619 (10.8%), 3:177 (3.1%), 4:243 (4.2%), 5:1341 (23.4%), 6:416 (7.3%), 7:1213 (21.2%), 8:482 (8.4%)
#
# Episode 111  | EpReward: 230.00 | MovingAvg(100): 335.20
# Episode 112  | EpReward: 300.00 | MovingAvg(100): 336.60
# Episode 113  | EpReward: 570.00 | MovingAvg(100): 339.50
# Episode 114  | EpReward: 300.00 | MovingAvg(100): 340.10
# Episode 115  | EpReward: 410.00 | MovingAvg(100): 342.30
# Episode 116  | EpReward: 180.00 | MovingAvg(100): 341.50
# Episode 117  | EpReward: 920.00 | MovingAvg(100): 345.60
# Episode 118  | EpReward: 1280.00 | MovingAvg(100): 354.40
# Episode 119  | EpReward: 300.00 | MovingAvg(100): 355.70
# Episode 120  | EpReward: 320.00 | MovingAvg(100): 354.40
#
# --- DEBUG 111-120 ---
# Avg PolicyLoss: -0.0223 | Avg ValueLoss: 6.0374 | Avg Entropy: 1.9697 | Avg TotalLoss: 2.8979
# Advantage μ: -0.0002 | min: -1.7207 | max: 1.3183
# Action distribution (last 10 eps): 0:536 (8.2%), 1:608 (9.3%), 2:437 (6.7%), 3:222 (3.4%), 4:315 (4.8%), 5:1341 (20.5%), 6:417 (6.4%), 7:2317 (35.5%), 8:337 (5.2%)
#
# Episode 121  | EpReward: 140.00 | MovingAvg(100): 354.10
# Episode 122  | EpReward: 320.00 | MovingAvg(100): 355.40
# Episode 123  | EpReward: 910.00 | MovingAvg(100): 362.70
# Episode 124  | EpReward: 610.00 | MovingAvg(100): 367.50
# Episode 125  | EpReward: 680.00 | MovingAvg(100): 372.40
# Episode 126  | EpReward: 540.00 | MovingAvg(100): 375.30
# Episode 127  | EpReward: 470.00 | MovingAvg(100): 377.70
# Episode 128  | EpReward: 380.00 | MovingAvg(100): 376.50
# Episode 129  | EpReward: 590.00 | MovingAvg(100): 381.40
# Episode 130  | EpReward: 1180.00 | MovingAvg(100): 391.70
#
# --- DEBUG 121-130 ---
# Avg PolicyLoss: 0.1752 | Avg ValueLoss: 18.4474 | Avg Entropy: 1.9317 | Avg TotalLoss: 9.3023
# Advantage μ: 0.0000 | min: -1.4098 | max: 1.5510
# Action distribution (last 10 eps): 0:500 (8.0%), 1:674 (10.8%), 2:551 (8.8%), 3:227 (3.6%), 4:334 (5.4%), 5:1535 (24.6%), 6:304 (4.9%), 7:1792 (28.7%), 8:318 (5.1%)
#
# Episode 131  | EpReward: 410.00 | MovingAvg(100): 394.50
# Episode 132  | EpReward: 390.00 | MovingAvg(100): 395.70
# Episode 133  | EpReward: 810.00 | MovingAvg(100): 394.90
# Episode 134  | EpReward: 430.00 | MovingAvg(100): 392.80
# Episode 135  | EpReward: 290.00 | MovingAvg(100): 394.40
# Episode 136  | EpReward: 940.00 | MovingAvg(100): 385.20
# Episode 137  | EpReward: 290.00 | MovingAvg(100): 382.80
# Episode 138  | EpReward: 310.00 | MovingAvg(100): 380.50
# Episode 139  | EpReward: 450.00 | MovingAvg(100): 378.60
# Episode 140  | EpReward: 600.00 | MovingAvg(100): 382.30
#
# --- DEBUG 131-140 ---
# Avg PolicyLoss: -0.0125 | Avg ValueLoss: 10.7796 | Avg Entropy: 1.9127 | Avg TotalLoss: 5.2816
# Advantage μ: 0.0001 | min: -1.2883 | max: 1.9008
# Action distribution (last 10 eps): 0:530 (9.8%), 1:511 (9.4%), 2:556 (10.3%), 3:323 (6.0%), 4:251 (4.6%), 5:1745 (32.2%), 6:244 (4.5%), 7:897 (16.6%), 8:355 (6.6%)
#
# Episode 141  | EpReward: 890.00 | MovingAvg(100): 388.30
# Episode 142  | EpReward: 310.00 | MovingAvg(100): 389.10
# Episode 143  | EpReward: 400.00 | MovingAvg(100): 391.30
# Episode 144  | EpReward: 250.00 | MovingAvg(100): 391.80
# Episode 145  | EpReward: 690.00 | MovingAvg(100): 397.30
# Episode 146  | EpReward: 900.00 | MovingAvg(100): 402.80
# Episode 147  | EpReward: 640.00 | MovingAvg(100): 407.00
# Episode 148  | EpReward: 380.00 | MovingAvg(100): 407.90
# Episode 149  | EpReward: 270.00 | MovingAvg(100): 407.80
# Episode 150  | EpReward: 340.00 | MovingAvg(100): 405.70
#
# --- DEBUG 141-150 ---
# Avg PolicyLoss: -0.1843 | Avg ValueLoss: 6.0739 | Avg Entropy: 1.8387 | Avg TotalLoss: 2.7608
# Advantage μ: -0.0000 | min: -1.5535 | max: 1.5904
# Action distribution (last 10 eps): 0:441 (8.7%), 1:394 (7.8%), 2:286 (5.7%), 3:267 (5.3%), 4:215 (4.3%), 5:2501 (49.6%), 6:204 (4.0%), 7:467 (9.3%), 8:266 (5.3%)
#
# Episode 151  | EpReward: 1150.00 | MovingAvg(100): 414.80
# Episode 152  | EpReward: 1900.00 | MovingAvg(100): 430.60
# Episode 153  | EpReward: 300.00 | MovingAvg(100): 423.90
# Episode 154  | EpReward: 420.00 | MovingAvg(100): 426.60
# Episode 155  | EpReward: 410.00 | MovingAvg(100): 424.60
# Episode 156  | EpReward: 350.00 | MovingAvg(100): 425.80
# Episode 157  | EpReward: 500.00 | MovingAvg(100): 428.40
# Episode 158  | EpReward: 440.00 | MovingAvg(100): 430.60
# Episode 159  | EpReward: 380.00 | MovingAvg(100): 431.80
# Episode 160  | EpReward: 520.00 | MovingAvg(100): 431.60
#
# --- DEBUG 151-160 ---
# Avg PolicyLoss: -0.0540 | Avg ValueLoss: 42.6614 | Avg Entropy: 1.7563 | Avg TotalLoss: 21.1889
# Advantage μ: 0.0001 | min: -1.7936 | max: 1.3656
# Action distribution (last 10 eps): 0:723 (12.9%), 1:420 (7.5%), 2:286 (5.1%), 3:395 (7.0%), 4:327 (5.8%), 5:2284 (40.8%), 6:192 (3.4%), 7:501 (8.9%), 8:476 (8.5%)
#
# Episode 161  | EpReward: 350.00 | MovingAvg(100): 434.40
# Episode 162  | EpReward: 280.00 | MovingAvg(100): 435.50
# Episode 163  | EpReward: 300.00 | MovingAvg(100): 435.30
# Episode 164  | EpReward: 660.00 | MovingAvg(100): 439.10
# Episode 165  | EpReward: 340.00 | MovingAvg(100): 440.40
# Episode 166  | EpReward: 530.00 | MovingAvg(100): 443.60
# Episode 167  | EpReward: 370.00 | MovingAvg(100): 444.70
# Episode 168  | EpReward: 440.00 | MovingAvg(100): 447.20
# Episode 169  | EpReward: 330.00 | MovingAvg(100): 444.10
# Episode 170  | EpReward: 970.00 | MovingAvg(100): 448.30
#
# --- DEBUG 161-170 ---
# Avg PolicyLoss: -0.0389 | Avg ValueLoss: 2.7677 | Avg Entropy: 2.1036 | Avg TotalLoss: 1.2398
# Advantage μ: -0.0001 | min: -1.3831 | max: 1.6635
# Action distribution (last 10 eps): 0:841 (15.2%), 1:439 (7.9%), 2:264 (4.8%), 3:586 (10.6%), 4:421 (7.6%), 5:1805 (32.7%), 6:187 (3.4%), 7:507 (9.2%), 8:474 (8.6%)
#
# Episode 171  | EpReward: 700.00 | MovingAvg(100): 454.30
# Episode 172  | EpReward: 390.00 | MovingAvg(100): 456.30
# Episode 173  | EpReward: 360.00 | MovingAvg(100): 457.70
# Episode 174  | EpReward: 380.00 | MovingAvg(100): 459.50
# Episode 175  | EpReward: 960.00 | MovingAvg(100): 466.90
# Episode 176  | EpReward: 420.00 | MovingAvg(100): 469.50
# Episode 177  | EpReward: 440.00 | MovingAvg(100): 471.40
# Episode 178  | EpReward: 660.00 | MovingAvg(100): 475.40
# Episode 179  | EpReward: 440.00 | MovingAvg(100): 478.20
# Episode 180  | EpReward: 440.00 | MovingAvg(100): 475.10
#
# --- DEBUG 171-180 ---
# Avg PolicyLoss: -0.0829 | Avg ValueLoss: 32.3444 | Avg Entropy: 1.8377 | Avg TotalLoss: 15.9974
# Advantage μ: 0.0002 | min: -1.7988 | max: 1.5753
# Action distribution (last 10 eps): 0:1426 (26.6%), 1:342 (6.4%), 2:175 (3.3%), 3:308 (5.8%), 4:325 (6.1%), 5:1549 (28.9%), 6:109 (2.0%), 7:430 (8.0%), 8:691 (12.9%)
#
# Episode 181  | EpReward: 970.00 | MovingAvg(100): 482.10
# Episode 182  | EpReward: 510.00 | MovingAvg(100): 484.10
# Episode 183  | EpReward: 630.00 | MovingAvg(100): 487.80
# Episode 184  | EpReward: 1020.00 | MovingAvg(100): 494.20
# Episode 185  | EpReward: 370.00 | MovingAvg(100): 496.40
# Episode 186  | EpReward: 390.00 | MovingAvg(100): 498.00
# Episode 187  | EpReward: 600.00 | MovingAvg(100): 497.70
# Episode 188  | EpReward: 360.00 | MovingAvg(100): 500.00
# Episode 189  | EpReward: 830.00 | MovingAvg(100): 505.60
# Episode 190  | EpReward: 340.00 | MovingAvg(100): 507.50
#
# --- DEBUG 181-190 ---
# Avg PolicyLoss: 0.0482 | Avg ValueLoss: 5.0797 | Avg Entropy: 1.9975 | Avg TotalLoss: 2.4881
# Advantage μ: -0.0001 | min: -1.6621 | max: 1.7538
# Action distribution (last 10 eps): 0:1546 (24.9%), 1:534 (8.6%), 2:241 (3.9%), 3:493 (7.9%), 4:493 (7.9%), 5:1555 (25.1%), 6:115 (1.9%), 7:437 (7.0%), 8:788 (12.7%)
#
# Episode 191  | EpReward: 310.00 | MovingAvg(100): 507.50
# Episode 192  | EpReward: 320.00 | MovingAvg(100): 508.80
# Episode 193  | EpReward: 350.00 | MovingAvg(100): 510.60
# Episode 194  | EpReward: 780.00 | MovingAvg(100): 517.10
# Episode 195  | EpReward: 390.00 | MovingAvg(100): 517.70
# Episode 196  | EpReward: 260.00 | MovingAvg(100): 518.00
# Episode 197  | EpReward: 410.00 | MovingAvg(100): 519.50
# Episode 198  | EpReward: 480.00 | MovingAvg(100): 521.80
# Episode 199  | EpReward: 280.00 | MovingAvg(100): 522.30
# Episode 200  | EpReward: 290.00 | MovingAvg(100): 523.20
#
# --- DEBUG 191-200 ---
# Avg PolicyLoss: 0.0071 | Avg ValueLoss: 219.7917 | Avg Entropy: 1.8347 | Avg TotalLoss: 109.8113
# Advantage μ: 0.0001 | min: -1.6628 | max: 1.8131
# Action distribution (last 10 eps): 0:730 (14.9%), 1:873 (17.8%), 2:193 (3.9%), 3:422 (8.6%), 4:353 (7.2%), 5:1080 (22.1%), 6:114 (2.3%), 7:447 (9.1%), 8:682 (13.9%)
#
# Episode 201  | EpReward: 440.00 | MovingAvg(100): 524.30
# Episode 202  | EpReward: 430.00 | MovingAvg(100): 526.30
# Episode 203  | EpReward: 720.00 | MovingAvg(100): 530.90
# Episode 204  | EpReward: 400.00 | MovingAvg(100): 529.00
# Episode 205  | EpReward: 390.00 | MovingAvg(100): 528.00
# Episode 206  | EpReward: 320.00 | MovingAvg(100): 521.30
# Episode 207  | EpReward: 360.00 | MovingAvg(100): 515.60
# Episode 208  | EpReward: 380.00 | MovingAvg(100): 514.30
# Episode 209  | EpReward: 300.00 | MovingAvg(100): 508.90
# Episode 210  | EpReward: 540.00 | MovingAvg(100): 509.20
#
# --- DEBUG 201-210 ---
# Avg PolicyLoss: 0.2670 | Avg ValueLoss: 360.9429 | Avg Entropy: 1.8928 | Avg TotalLoss: 180.6439
# Advantage μ: 0.0001 | min: -1.6811 | max: 1.8168
# Action distribution (last 10 eps): 0:671 (12.0%), 1:937 (16.7%), 2:243 (4.3%), 3:580 (10.4%), 4:433 (7.7%), 5:1296 (23.1%), 6:211 (3.8%), 7:561 (10.0%), 8:667 (11.9%)
#
# Episode 211  | EpReward: 300.00 | MovingAvg(100): 509.90
# Episode 212  | EpReward: 280.00 | MovingAvg(100): 509.70
# Episode 213  | EpReward: 380.00 | MovingAvg(100): 507.80
# Episode 214  | EpReward: 400.00 | MovingAvg(100): 508.80
# Episode 215  | EpReward: 300.00 | MovingAvg(100): 507.70
# Episode 216  | EpReward: 330.00 | MovingAvg(100): 509.20
# Episode 217  | EpReward: 310.00 | MovingAvg(100): 503.10
# Episode 218  | EpReward: 360.00 | MovingAvg(100): 493.90
# Episode 219  | EpReward: 360.00 | MovingAvg(100): 494.50
# Episode 220  | EpReward: 340.00 | MovingAvg(100): 494.70
#
# --- DEBUG 211-220 ---
# Avg PolicyLoss: 0.0338 | Avg ValueLoss: 3.2142 | Avg Entropy: 2.1209 | Avg TotalLoss: 1.5348
# Advantage μ: 0.0001 | min: -1.7242 | max: 1.8105
# Action distribution (last 10 eps): 0:563 (12.5%), 1:620 (13.7%), 2:207 (4.6%), 3:448 (9.9%), 4:297 (6.6%), 5:1334 (29.5%), 6:215 (4.8%), 7:351 (7.8%), 8:486 (10.7%)
#
# Episode 221  | EpReward: 310.00 | MovingAvg(100): 496.40
# Episode 222  | EpReward: 330.00 | MovingAvg(100): 496.50
# Episode 223  | EpReward: 510.00 | MovingAvg(100): 492.50
# Episode 224  | EpReward: 370.00 | MovingAvg(100): 490.10
# Episode 225  | EpReward: 360.00 | MovingAvg(100): 486.90
# Episode 226  | EpReward: 1370.00 | MovingAvg(100): 495.20
# Episode 227  | EpReward: 1130.00 | MovingAvg(100): 501.80
# Episode 228  | EpReward: 400.00 | MovingAvg(100): 502.00
# Episode 229  | EpReward: 340.00 | MovingAvg(100): 499.50
# Episode 230  | EpReward: 1050.00 | MovingAvg(100): 498.20
#
# --- DEBUG 221-230 ---
# Avg PolicyLoss: 0.1201 | Avg ValueLoss: 810.5402 | Avg Entropy: 1.6131 | Avg TotalLoss: 405.3096
# Advantage μ: 0.0000 | min: -1.6115 | max: 1.5496
# Action distribution (last 10 eps): 0:782 (14.7%), 1:880 (16.5%), 2:170 (3.2%), 3:402 (7.5%), 4:176 (3.3%), 5:1309 (24.6%), 6:211 (4.0%), 7:264 (5.0%), 8:1135 (21.3%)
#
# Episode 231  | EpReward: 430.00 | MovingAvg(100): 498.40
# Episode 232  | EpReward: 410.00 | MovingAvg(100): 498.60
# Episode 233  | EpReward: 460.00 | MovingAvg(100): 495.10
# Episode 234  | EpReward: 500.00 | MovingAvg(100): 495.80
# Episode 235  | EpReward: 400.00 | MovingAvg(100): 496.90
# Episode 236  | EpReward: 420.00 | MovingAvg(100): 491.70
# Episode 237  | EpReward: 380.00 | MovingAvg(100): 492.60
# Episode 238  | EpReward: 300.00 | MovingAvg(100): 492.50
# Episode 239  | EpReward: 270.00 | MovingAvg(100): 490.70
# Episode 240  | EpReward: 600.00 | MovingAvg(100): 490.70
#
# --- DEBUG 231-240 ---
# Avg PolicyLoss: 0.0570 | Avg ValueLoss: 4.9581 | Avg Entropy: 1.9891 | Avg TotalLoss: 2.4366
# Advantage μ: 0.0000 | min: -1.7124 | max: 1.6487
# Action distribution (last 10 eps): 0:782 (15.5%), 1:1143 (22.7%), 2:209 (4.1%), 3:404 (8.0%), 4:195 (3.9%), 5:1060 (21.0%), 6:170 (3.4%), 7:260 (5.2%), 8:818 (16.2%)
#
# Episode 241  | EpReward: 290.00 | MovingAvg(100): 484.70
# Episode 242  | EpReward: 330.00 | MovingAvg(100): 484.90
# Episode 243  | EpReward: 350.00 | MovingAvg(100): 484.40
# Episode 244  | EpReward: 370.00 | MovingAvg(100): 485.60
# Episode 245  | EpReward: 340.00 | MovingAvg(100): 482.10
# Episode 246  | EpReward: 1050.00 | MovingAvg(100): 483.60
# Episode 247  | EpReward: 290.00 | MovingAvg(100): 480.10
# Episode 248  | EpReward: 430.00 | MovingAvg(100): 480.60
# Episode 249  | EpReward: 390.00 | MovingAvg(100): 481.80
# Episode 250  | EpReward: 420.00 | MovingAvg(100): 482.60
#
# --- DEBUG 241-250 ---
# Avg PolicyLoss: 0.0621 | Avg ValueLoss: 3.6390 | Avg Entropy: 1.9070 | Avg TotalLoss: 1.7863
# Advantage μ: 0.0000 | min: -1.8377 | max: 1.3168
# Action distribution (last 10 eps): 0:809 (17.9%), 1:976 (21.6%), 2:112 (2.5%), 3:547 (12.1%), 4:179 (4.0%), 5:1010 (22.3%), 6:145 (3.2%), 7:207 (4.6%), 8:538 (11.9%)
#
# Episode 251  | EpReward: 620.00 | MovingAvg(100): 477.30
# Episode 252  | EpReward: 360.00 | MovingAvg(100): 461.90
# Episode 253  | EpReward: 330.00 | MovingAvg(100): 462.20
# Episode 254  | EpReward: 360.00 | MovingAvg(100): 461.60
# Episode 255  | EpReward: 390.00 | MovingAvg(100): 461.40
# Episode 256  | EpReward: 320.00 | MovingAvg(100): 461.10
# Episode 257  | EpReward: 2000.00 | MovingAvg(100): 476.10
# Episode 258  | EpReward: 480.00 | MovingAvg(100): 476.50
# Episode 259  | EpReward: 480.00 | MovingAvg(100): 477.50
# Episode 260  | EpReward: 310.00 | MovingAvg(100): 475.40
#
# --- DEBUG 251-260 ---
# Avg PolicyLoss: 0.2342 | Avg ValueLoss: 3.8478 | Avg Entropy: 1.9380 | Avg TotalLoss: 2.0612
# Advantage μ: 0.0001 | min: -1.8556 | max: 1.8109
# Action distribution (last 10 eps): 0:756 (14.5%), 1:979 (18.8%), 2:180 (3.5%), 3:597 (11.5%), 4:173 (3.3%), 5:1487 (28.6%), 6:255 (4.9%), 7:305 (5.9%), 8:469 (9.0%)
#
# Episode 261  | EpReward: 320.00 | MovingAvg(100): 475.10
# Episode 262  | EpReward: 490.00 | MovingAvg(100): 477.20
# Episode 263  | EpReward: 510.00 | MovingAvg(100): 479.30
# Episode 264  | EpReward: 350.00 | MovingAvg(100): 476.20
# Episode 265  | EpReward: 320.00 | MovingAvg(100): 476.00
# Episode 266  | EpReward: 360.00 | MovingAvg(100): 474.30
# Episode 267  | EpReward: 390.00 | MovingAvg(100): 474.50
# Episode 268  | EpReward: 350.00 | MovingAvg(100): 473.60
# Episode 269  | EpReward: 390.00 | MovingAvg(100): 474.20
# Episode 270  | EpReward: 320.00 | MovingAvg(100): 467.70
#
# --- DEBUG 261-270 ---
# Avg PolicyLoss: 0.1816 | Avg ValueLoss: 3.7272 | Avg Entropy: 1.9831 | Avg TotalLoss: 1.9460
# Advantage μ: 0.0000 | min: -1.6648 | max: 1.3920
# Action distribution (last 10 eps): 0:753 (15.6%), 1:977 (20.3%), 2:158 (3.3%), 3:598 (12.4%), 4:167 (3.5%), 5:1357 (28.2%), 6:243 (5.0%), 7:218 (4.5%), 8:341 (7.1%)
#
# Episode 271  | EpReward: 320.00 | MovingAvg(100): 463.90
# Episode 272  | EpReward: 640.00 | MovingAvg(100): 466.40
# Episode 273  | EpReward: 320.00 | MovingAvg(100): 466.00
# Episode 274  | EpReward: 280.00 | MovingAvg(100): 465.00
# Episode 275  | EpReward: 530.00 | MovingAvg(100): 460.70
# Episode 276  | EpReward: 290.00 | MovingAvg(100): 459.40
# Episode 277  | EpReward: 360.00 | MovingAvg(100): 458.60
# Episode 278  | EpReward: 300.00 | MovingAvg(100): 455.00
# Episode 279  | EpReward: 410.00 | MovingAvg(100): 454.70
# Episode 280  | EpReward: 290.00 | MovingAvg(100): 453.20
#
# --- DEBUG 271-280 ---
# Avg PolicyLoss: 0.0524 | Avg ValueLoss: 1.8858 | Avg Entropy: 2.0323 | Avg TotalLoss: 0.8937
# Advantage μ: -0.0000 | min: -1.2350 | max: 1.4142
# Action distribution (last 10 eps): 0:741 (16.0%), 1:576 (12.4%), 2:172 (3.7%), 3:402 (8.7%), 4:180 (3.9%), 5:1692 (36.6%), 6:275 (5.9%), 7:232 (5.0%), 8:358 (7.7%)
#
# Episode 281  | EpReward: 320.00 | MovingAvg(100): 446.70
# Episode 282  | EpReward: 260.00 | MovingAvg(100): 444.20
# Episode 283  | EpReward: 390.00 | MovingAvg(100): 441.80
# Episode 284  | EpReward: 360.00 | MovingAvg(100): 435.20
# Episode 285  | EpReward: 340.00 | MovingAvg(100): 434.90
# Episode 286  | EpReward: 330.00 | MovingAvg(100): 434.30
# Episode 287  | EpReward: 230.00 | MovingAvg(100): 430.60
# Episode 288  | EpReward: 310.00 | MovingAvg(100): 430.10
# Episode 289  | EpReward: 290.00 | MovingAvg(100): 424.70
# Episode 290  | EpReward: 1120.00 | MovingAvg(100): 432.50
#
# --- DEBUG 281-290 ---
# Avg PolicyLoss: -0.0237 | Avg ValueLoss: 25.2338 | Avg Entropy: 1.7247 | Avg TotalLoss: 12.5069
# Advantage μ: 0.0004 | min: -1.5600 | max: 1.5043
# Action distribution (last 10 eps): 0:814 (18.2%), 1:354 (7.9%), 2:165 (3.7%), 3:322 (7.2%), 4:177 (4.0%), 5:1902 (42.6%), 6:232 (5.2%), 7:161 (3.6%), 8:337 (7.5%)
#
# Episode 291  | EpReward: 270.00 | MovingAvg(100): 432.10
# Episode 292  | EpReward: 290.00 | MovingAvg(100): 431.80
# Episode 293  | EpReward: 370.00 | MovingAvg(100): 432.00
# Episode 294  | EpReward: 270.00 | MovingAvg(100): 426.90
# Episode 295  | EpReward: 280.00 | MovingAvg(100): 425.80
# Episode 296  | EpReward: 330.00 | MovingAvg(100): 426.50
# Episode 297  | EpReward: 450.00 | MovingAvg(100): 426.90
# Episode 298  | EpReward: 390.00 | MovingAvg(100): 426.00
# Episode 299  | EpReward: 340.00 | MovingAvg(100): 426.60
# Episode 300  | EpReward: 360.00 | MovingAvg(100): 427.30
#
# --- DEBUG 291-300 ---
# Avg PolicyLoss: -0.0643 | Avg ValueLoss: 2.1269 | Avg Entropy: 2.0055 | Avg TotalLoss: 0.8989
# Advantage μ: 0.0000 | min: -1.4124 | max: 1.1795
# Action distribution (last 10 eps): 0:817 (18.9%), 1:382 (8.8%), 2:194 (4.5%), 3:343 (7.9%), 4:193 (4.5%), 5:1619 (37.5%), 6:223 (5.2%), 7:212 (4.9%), 8:338 (7.8%)
#
# Episode 301  | EpReward: 370.00 | MovingAvg(100): 426.60
# Episode 302  | EpReward: 390.00 | MovingAvg(100): 426.20
# Episode 303  | EpReward: 420.00 | MovingAvg(100): 423.20
# Episode 304  | EpReward: 250.00 | MovingAvg(100): 421.70
# Episode 305  | EpReward: 330.00 | MovingAvg(100): 421.10
# Episode 306  | EpReward: 350.00 | MovingAvg(100): 421.40
# Episode 307  | EpReward: 280.00 | MovingAvg(100): 420.60
# Episode 308  | EpReward: 650.00 | MovingAvg(100): 423.30
# Episode 309  | EpReward: 280.00 | MovingAvg(100): 423.10
# Episode 310  | EpReward: 390.00 | MovingAvg(100): 421.60
#
# --- DEBUG 301-310 ---
# Avg PolicyLoss: 0.0609 | Avg ValueLoss: 2.5155 | Avg Entropy: 1.9614 | Avg TotalLoss: 1.2206
# Advantage μ: -0.0000 | min: -1.7710 | max: 1.5042
# Action distribution (last 10 eps): 0:726 (16.1%), 1:368 (8.1%), 2:240 (5.3%), 3:348 (7.7%), 4:223 (4.9%), 5:1877 (41.6%), 6:193 (4.3%), 7:231 (5.1%), 8:311 (6.9%)
#
# Episode 311  | EpReward: 1100.00 | MovingAvg(100): 429.60
# Episode 312  | EpReward: 410.00 | MovingAvg(100): 430.90
# Episode 313  | EpReward: 350.00 | MovingAvg(100): 430.60
# Episode 314  | EpReward: 240.00 | MovingAvg(100): 429.00
# Episode 315  | EpReward: 320.00 | MovingAvg(100): 429.20
# Episode 316  | EpReward: 330.00 | MovingAvg(100): 429.20
# Episode 317  | EpReward: 990.00 | MovingAvg(100): 436.00
# Episode 318  | EpReward: 340.00 | MovingAvg(100): 435.80
# Episode 319  | EpReward: 270.00 | MovingAvg(100): 434.90
# Episode 320  | EpReward: 290.00 | MovingAvg(100): 434.40
#
# --- DEBUG 311-320 ---
# Avg PolicyLoss: -0.0624 | Avg ValueLoss: 8.1029 | Avg Entropy: 1.7841 | Avg TotalLoss: 3.8999
# Advantage μ: 0.0003 | min: -1.8913 | max: 1.4927
# Action distribution (last 10 eps): 0:887 (19.5%), 1:388 (8.5%), 2:255 (5.6%), 3:299 (6.6%), 4:232 (5.1%), 5:1798 (39.5%), 6:185 (4.1%), 7:265 (5.8%), 8:238 (5.2%)
#
# Episode 321  | EpReward: 880.00 | MovingAvg(100): 440.10
# Episode 322  | EpReward: 600.00 | MovingAvg(100): 442.80
# Episode 323  | EpReward: 220.00 | MovingAvg(100): 439.90
# Episode 324  | EpReward: 310.00 | MovingAvg(100): 439.30
# Episode 325  | EpReward: 280.00 | MovingAvg(100): 438.50
# Episode 326  | EpReward: 400.00 | MovingAvg(100): 428.80
# Episode 327  | EpReward: 210.00 | MovingAvg(100): 419.60
# Episode 328  | EpReward: 690.00 | MovingAvg(100): 422.50
# Episode 329  | EpReward: 770.00 | MovingAvg(100): 426.80
# Episode 330  | EpReward: 560.00 | MovingAvg(100): 421.90
#
# --- DEBUG 321-330 ---
# Avg PolicyLoss: 0.0057 | Avg ValueLoss: 7.9163 | Avg Entropy: 1.6169 | Avg TotalLoss: 3.8830
# Advantage μ: 0.0000 | min: -1.6336 | max: 1.7318
# Action distribution (last 10 eps): 0:1006 (19.8%), 1:255 (5.0%), 2:226 (4.4%), 3:242 (4.8%), 4:253 (5.0%), 5:2418 (47.5%), 6:157 (3.1%), 7:292 (5.7%), 8:242 (4.8%)
#
# Episode 331  | EpReward: 880.00 | MovingAvg(100): 426.40
# Episode 332  | EpReward: 520.00 | MovingAvg(100): 427.50
# Episode 333  | EpReward: 560.00 | MovingAvg(100): 428.50
# Episode 334  | EpReward: 340.00 | MovingAvg(100): 426.90
# Episode 335  | EpReward: 370.00 | MovingAvg(100): 426.60
# Episode 336  | EpReward: 560.00 | MovingAvg(100): 428.00
# Episode 337  | EpReward: 290.00 | MovingAvg(100): 427.10
# Episode 338  | EpReward: 400.00 | MovingAvg(100): 428.10
# Episode 339  | EpReward: 680.00 | MovingAvg(100): 432.20
# Episode 340  | EpReward: 400.00 | MovingAvg(100): 430.20
#
# --- DEBUG 331-340 ---
# Avg PolicyLoss: 0.0134 | Avg ValueLoss: 2.0908 | Avg Entropy: 1.9691 | Avg TotalLoss: 0.9604
# Advantage μ: 0.0002 | min: -1.6128 | max: 1.5377
# Action distribution (last 10 eps): 0:935 (16.2%), 1:343 (5.9%), 2:360 (6.2%), 3:337 (5.8%), 4:363 (6.3%), 5:2316 (40.2%), 6:247 (4.3%), 7:530 (9.2%), 8:337 (5.8%)
#
# Episode 341  | EpReward: 480.00 | MovingAvg(100): 432.10
# Episode 342  | EpReward: 630.00 | MovingAvg(100): 435.10
# Episode 343  | EpReward: 1300.00 | MovingAvg(100): 444.60
# Episode 344  | EpReward: 890.00 | MovingAvg(100): 449.80
# Episode 345  | EpReward: 530.00 | MovingAvg(100): 451.70
# Episode 346  | EpReward: 280.00 | MovingAvg(100): 444.00
# Episode 347  | EpReward: 680.00 | MovingAvg(100): 447.90
# Episode 348  | EpReward: 330.00 | MovingAvg(100): 446.90
# Episode 349  | EpReward: 530.00 | MovingAvg(100): 448.30
# Episode 350  | EpReward: 330.00 | MovingAvg(100): 447.40
#
# --- DEBUG 341-350 ---
# Avg PolicyLoss: 0.2188 | Avg ValueLoss: 9.6814 | Avg Entropy: 1.5877 | Avg TotalLoss: 4.9801
# Advantage μ: -0.0000 | min: -1.8935 | max: 1.4820
# Action distribution (last 10 eps): 0:839 (16.2%), 1:243 (4.7%), 2:194 (3.8%), 3:183 (3.5%), 4:293 (5.7%), 5:2728 (52.8%), 6:149 (2.9%), 7:339 (6.6%), 8:197 (3.8%)
#
# Episode 351  | EpReward: 550.00 | MovingAvg(100): 446.70
# Episode 352  | EpReward: 270.00 | MovingAvg(100): 445.80
# Episode 353  | EpReward: 480.00 | MovingAvg(100): 447.30
# Episode 354  | EpReward: 380.00 | MovingAvg(100): 447.50
# Episode 355  | EpReward: 520.00 | MovingAvg(100): 448.80
# Episode 356  | EpReward: 470.00 | MovingAvg(100): 450.30
# Episode 357  | EpReward: 1240.00 | MovingAvg(100): 442.70
# Episode 358  | EpReward: 480.00 | MovingAvg(100): 442.70
# Episode 359  | EpReward: 430.00 | MovingAvg(100): 442.20
# Episode 360  | EpReward: 350.00 | MovingAvg(100): 442.60
#
# --- DEBUG 351-360 ---
# Avg PolicyLoss: -0.2777 | Avg ValueLoss: 4.4920 | Avg Entropy: 1.4843 | Avg TotalLoss: 1.8941
# Advantage μ: -0.0006 | min: -1.7062 | max: 1.6954
# Action distribution (last 10 eps): 0:598 (11.2%), 1:206 (3.9%), 2:197 (3.7%), 3:170 (3.2%), 4:247 (4.6%), 5:3275 (61.5%), 6:109 (2.0%), 7:343 (6.4%), 8:182 (3.4%)
#
# Episode 361  | EpReward: 220.00 | MovingAvg(100): 441.60
# Episode 362  | EpReward: 380.00 | MovingAvg(100): 440.50
# Episode 363  | EpReward: 840.00 | MovingAvg(100): 443.80
# Episode 364  | EpReward: 480.00 | MovingAvg(100): 445.10
# Episode 365  | EpReward: 650.00 | MovingAvg(100): 448.40
# Episode 366  | EpReward: 400.00 | MovingAvg(100): 448.80
# Episode 367  | EpReward: 360.00 | MovingAvg(100): 448.50
# Episode 368  | EpReward: 320.00 | MovingAvg(100): 448.20
# Episode 369  | EpReward: 640.00 | MovingAvg(100): 450.70
# Episode 370  | EpReward: 400.00 | MovingAvg(100): 451.50
#
# --- DEBUG 361-370 ---
# Avg PolicyLoss: 0.0242 | Avg ValueLoss: 3.2317 | Avg Entropy: 1.7485 | Avg TotalLoss: 1.5526
# Advantage μ: -0.0000 | min: -1.7850 | max: 1.4029
# Action distribution (last 10 eps): 0:729 (14.2%), 1:254 (5.0%), 2:194 (3.8%), 3:161 (3.1%), 4:344 (6.7%), 5:2782 (54.2%), 6:109 (2.1%), 7:337 (6.6%), 8:221 (4.3%)
#
# Episode 371  | EpReward: 510.00 | MovingAvg(100): 453.40
# Episode 372  | EpReward: 470.00 | MovingAvg(100): 451.70
# Episode 373  | EpReward: 630.00 | MovingAvg(100): 454.80
# Episode 374  | EpReward: 690.00 | MovingAvg(100): 458.90
# Episode 375  | EpReward: 420.00 | MovingAvg(100): 457.80
# Episode 376  | EpReward: 440.00 | MovingAvg(100): 459.30
# Episode 377  | EpReward: 540.00 | MovingAvg(100): 461.10
# Episode 378  | EpReward: 510.00 | MovingAvg(100): 463.20
# Episode 379  | EpReward: 690.00 | MovingAvg(100): 466.00
# Episode 380  | EpReward: 730.00 | MovingAvg(100): 470.40
#
# --- DEBUG 371-380 ---
# Avg PolicyLoss: -0.0071 | Avg ValueLoss: 37.2288 | Avg Entropy: 1.6911 | Avg TotalLoss: 18.5227
# Advantage μ: -0.0011 | min: -1.8333 | max: 1.4828
# Action distribution (last 10 eps): 0:911 (15.2%), 1:336 (5.6%), 2:315 (5.3%), 3:269 (4.5%), 4:392 (6.5%), 5:2904 (48.4%), 6:156 (2.6%), 7:402 (6.7%), 8:312 (5.2%)
#
# Episode 381  | EpReward: 330.00 | MovingAvg(100): 470.50
# Episode 382  | EpReward: 470.00 | MovingAvg(100): 472.60
# Episode 383  | EpReward: 320.00 | MovingAvg(100): 471.90
# Episode 384  | EpReward: 520.00 | MovingAvg(100): 473.50
# Episode 385  | EpReward: 380.00 | MovingAvg(100): 473.90
# Episode 386  | EpReward: 340.00 | MovingAvg(100): 474.00
# Episode 387  | EpReward: 320.00 | MovingAvg(100): 474.90
# Episode 388  | EpReward: 520.00 | MovingAvg(100): 477.00
# Episode 389  | EpReward: 750.00 | MovingAvg(100): 481.60
# Episode 390  | EpReward: 470.00 | MovingAvg(100): 475.10
#
# --- DEBUG 381-390 ---
# Avg PolicyLoss: -0.0573 | Avg ValueLoss: 4.2827 | Avg Entropy: 1.5305 | Avg TotalLoss: 2.0075
# Advantage μ: 0.0000 | min: -1.7309 | max: 1.8658
# Action distribution (last 10 eps): 0:663 (13.5%), 1:212 (4.3%), 2:177 (3.6%), 3:145 (3.0%), 4:205 (4.2%), 5:2988 (60.8%), 6:118 (2.4%), 7:256 (5.2%), 8:149 (3.0%)
#
# Episode 391  | EpReward: 520.00 | MovingAvg(100): 477.60
# Episode 392  | EpReward: 600.00 | MovingAvg(100): 480.70
# Episode 393  | EpReward: 230.00 | MovingAvg(100): 479.30
# Episode 394  | EpReward: 410.00 | MovingAvg(100): 480.70
# Episode 395  | EpReward: 340.00 | MovingAvg(100): 481.30
# Episode 396  | EpReward: 290.00 | MovingAvg(100): 480.90
# Episode 397  | EpReward: 300.00 | MovingAvg(100): 479.40
# Episode 398  | EpReward: 240.00 | MovingAvg(100): 477.90
# Episode 399  | EpReward: 640.00 | MovingAvg(100): 480.90
# Episode 400  | EpReward: 270.00 | MovingAvg(100): 480.00
#
# --- DEBUG 391-400 ---
# Avg PolicyLoss: 0.1402 | Avg ValueLoss: 2.1256 | Avg Entropy: 1.5063 | Avg TotalLoss: 1.1276
# Advantage μ: -0.0000 | min: -1.6817 | max: 1.4851
# Action distribution (last 10 eps): 0:698 (15.0%), 1:180 (3.9%), 2:139 (3.0%), 3:119 (2.6%), 4:181 (3.9%), 5:2912 (62.6%), 6:96 (2.1%), 7:178 (3.8%), 8:147 (3.2%)
#
# Episode 401  | EpReward: 390.00 | MovingAvg(100): 480.20
# Episode 402  | EpReward: 510.00 | MovingAvg(100): 481.40
# Episode 403  | EpReward: 390.00 | MovingAvg(100): 481.10
# Episode 404  | EpReward: 620.00 | MovingAvg(100): 484.80
# Episode 405  | EpReward: 910.00 | MovingAvg(100): 490.60
# Episode 406  | EpReward: 670.00 | MovingAvg(100): 493.80
# Episode 407  | EpReward: 510.00 | MovingAvg(100): 496.10
# Episode 408  | EpReward: 570.00 | MovingAvg(100): 495.30
# Episode 409  | EpReward: 510.00 | MovingAvg(100): 497.60
# Episode 410  | EpReward: 420.00 | MovingAvg(100): 497.90
#
# --- DEBUG 401-410 ---
# Avg PolicyLoss: 0.1752 | Avg ValueLoss: 1.9458 | Avg Entropy: 1.7621 | Avg TotalLoss: 1.0600
# Advantage μ: -0.0001 | min: -1.5681 | max: 1.5915
# Action distribution (last 10 eps): 0:924 (15.2%), 1:367 (6.0%), 2:236 (3.9%), 3:201 (3.3%), 4:316 (5.2%), 5:3280 (53.8%), 6:202 (3.3%), 7:286 (4.7%), 8:286 (4.7%)
#
# Episode 411  | EpReward: 530.00 | MovingAvg(100): 492.20
# Episode 412  | EpReward: 490.00 | MovingAvg(100): 493.00
# Episode 413  | EpReward: 240.00 | MovingAvg(100): 491.90
# Episode 414  | EpReward: 240.00 | MovingAvg(100): 491.90
# Episode 415  | EpReward: 880.00 | MovingAvg(100): 497.50
# Episode 416  | EpReward: 370.00 | MovingAvg(100): 497.90
# Episode 417  | EpReward: 510.00 | MovingAvg(100): 493.10
# Episode 418  | EpReward: 310.00 | MovingAvg(100): 492.80
# Episode 419  | EpReward: 740.00 | MovingAvg(100): 497.50
# Episode 420  | EpReward: 520.00 | MovingAvg(100): 499.80
#
# --- DEBUG 411-420 ---
# Avg PolicyLoss: -0.0268 | Avg ValueLoss: 4.3065 | Avg Entropy: 1.5990 | Avg TotalLoss: 2.0465
# Advantage μ: 0.0009 | min: -1.4138 | max: 1.5119
# Action distribution (last 10 eps): 0:582 (11.0%), 1:312 (5.9%), 2:260 (4.9%), 3:197 (3.7%), 4:299 (5.6%), 5:2912 (54.9%), 6:173 (3.3%), 7:298 (5.6%), 8:267 (5.0%)
#
# Episode 421  | EpReward: 1370.00 | MovingAvg(100): 504.70
# Episode 422  | EpReward: 520.00 | MovingAvg(100): 503.90
# Episode 423  | EpReward: 600.00 | MovingAvg(100): 507.70
# Episode 424  | EpReward: 210.00 | MovingAvg(100): 506.70
# Episode 425  | EpReward: 1080.00 | MovingAvg(100): 514.70
# Episode 426  | EpReward: 480.00 | MovingAvg(100): 515.50
# Episode 427  | EpReward: 230.00 | MovingAvg(100): 515.70
# Episode 428  | EpReward: 280.00 | MovingAvg(100): 511.60
# Episode 429  | EpReward: 500.00 | MovingAvg(100): 508.90
# Episode 430  | EpReward: 250.00 | MovingAvg(100): 505.80
#
# --- DEBUG 421-430 ---
# Avg PolicyLoss: 0.0501 | Avg ValueLoss: 6.3905 | Avg Entropy: 1.3315 | Avg TotalLoss: 3.1788
# Advantage μ: 0.0000 | min: -1.6659 | max: 1.1631
# Action distribution (last 10 eps): 0:460 (9.9%), 1:212 (4.6%), 2:226 (4.9%), 3:160 (3.5%), 4:190 (4.1%), 5:2853 (61.6%), 6:103 (2.2%), 7:210 (4.5%), 8:216 (4.7%)
#
# Episode 431  | EpReward: 230.00 | MovingAvg(100): 499.30
# Episode 432  | EpReward: 650.00 | MovingAvg(100): 500.60
# Episode 433  | EpReward: 220.00 | MovingAvg(100): 497.20
# Episode 434  | EpReward: 560.00 | MovingAvg(100): 499.40
# Episode 435  | EpReward: 250.00 | MovingAvg(100): 498.20
# Episode 436  | EpReward: 800.00 | MovingAvg(100): 500.60
# Episode 437  | EpReward: 460.00 | MovingAvg(100): 502.30
# Episode 438  | EpReward: 360.00 | MovingAvg(100): 501.90
# Episode 439  | EpReward: 390.00 | MovingAvg(100): 499.00
# Episode 440  | EpReward: 330.00 | MovingAvg(100): 498.30
#
# --- DEBUG 431-440 ---
# Avg PolicyLoss: 0.0335 | Avg ValueLoss: 6.8579 | Avg Entropy: 1.2515 | Avg TotalLoss: 3.3999
# Advantage μ: 0.0000 | min: -1.8789 | max: 1.7978
# Action distribution (last 10 eps): 0:410 (9.5%), 1:181 (4.2%), 2:218 (5.0%), 3:136 (3.1%), 4:143 (3.3%), 5:2761 (63.9%), 6:124 (2.9%), 7:193 (4.5%), 8:156 (3.6%)
#
# Episode 441  | EpReward: 240.00 | MovingAvg(100): 495.90
# Episode 442  | EpReward: 1150.00 | MovingAvg(100): 501.10
# Episode 443  | EpReward: 350.00 | MovingAvg(100): 491.60
# Episode 444  | EpReward: 580.00 | MovingAvg(100): 488.50
# Episode 445  | EpReward: 940.00 | MovingAvg(100): 492.60
# Episode 446  | EpReward: 410.00 | MovingAvg(100): 493.90
# Episode 447  | EpReward: 210.00 | MovingAvg(100): 489.20
# Episode 448  | EpReward: 620.00 | MovingAvg(100): 492.10
# Episode 449  | EpReward: 250.00 | MovingAvg(100): 489.30
# Episode 450  | EpReward: 230.00 | MovingAvg(100): 488.30
#
# --- DEBUG 441-450 ---
# Avg PolicyLoss: -0.1507 | Avg ValueLoss: 443.8107 | Avg Entropy: 1.5701 | Avg TotalLoss: 221.6762
# Advantage μ: 0.0005 | min: -1.6050 | max: 1.7025
# Action distribution (last 10 eps): 0:535 (11.3%), 1:220 (4.6%), 2:357 (7.5%), 3:189 (4.0%), 4:193 (4.1%), 5:2638 (55.5%), 6:187 (3.9%), 7:211 (4.4%), 8:225 (4.7%)
#
# Episode 451  | EpReward: 740.00 | MovingAvg(100): 490.20
# Episode 452  | EpReward: 680.00 | MovingAvg(100): 494.30
# Episode 453  | EpReward: 300.00 | MovingAvg(100): 492.50
# Episode 454  | EpReward: 470.00 | MovingAvg(100): 493.40
# Episode 455  | EpReward: 640.00 | MovingAvg(100): 494.60
# Episode 456  | EpReward: 500.00 | MovingAvg(100): 494.90
# Episode 457  | EpReward: 220.00 | MovingAvg(100): 484.70
# Episode 458  | EpReward: 590.00 | MovingAvg(100): 485.80
# Episode 459  | EpReward: 500.00 | MovingAvg(100): 486.50
# Episode 460  | EpReward: 570.00 | MovingAvg(100): 488.70
#
# --- DEBUG 451-460 ---
# Avg PolicyLoss: -0.0049 | Avg ValueLoss: 2.8238 | Avg Entropy: 1.5920 | Avg TotalLoss: 1.3274
# Advantage μ: 0.0001 | min: -1.6471 | max: 1.4192
# Action distribution (last 10 eps): 0:621 (11.0%), 1:225 (4.0%), 2:393 (7.0%), 3:168 (3.0%), 4:178 (3.2%), 5:3363 (59.6%), 6:232 (4.1%), 7:203 (3.6%), 8:258 (4.6%)
#
# Episode 461  | EpReward: 530.00 | MovingAvg(100): 491.80
# Episode 462  | EpReward: 290.00 | MovingAvg(100): 490.90
# Episode 463  | EpReward: 1120.00 | MovingAvg(100): 493.70
# Episode 464  | EpReward: 290.00 | MovingAvg(100): 491.80
# Episode 465  | EpReward: 320.00 | MovingAvg(100): 488.50
# Episode 466  | EpReward: 750.00 | MovingAvg(100): 492.00
# Episode 467  | EpReward: 390.00 | MovingAvg(100): 492.30
# Episode 468  | EpReward: 250.00 | MovingAvg(100): 491.60
# Episode 469  | EpReward: 210.00 | MovingAvg(100): 487.30
# Episode 470  | EpReward: 790.00 | MovingAvg(100): 491.20
#
# --- DEBUG 461-470 ---
# Avg PolicyLoss: 0.0656 | Avg ValueLoss: 5.1968 | Avg Entropy: 1.3270 | Avg TotalLoss: 2.5977
# Advantage μ: 0.0013 | min: -1.4082 | max: 1.6491
# Action distribution (last 10 eps): 0:440 (8.8%), 1:168 (3.3%), 2:392 (7.8%), 3:138 (2.7%), 4:214 (4.3%), 5:3084 (61.3%), 6:156 (3.1%), 7:183 (3.6%), 8:252 (5.0%)
#
# Episode 471  | EpReward: 1090.00 | MovingAvg(100): 497.00
# Episode 472  | EpReward: 990.00 | MovingAvg(100): 502.20
# Episode 473  | EpReward: 730.00 | MovingAvg(100): 503.20
# Episode 474  | EpReward: 580.00 | MovingAvg(100): 502.10
# Episode 475  | EpReward: 350.00 | MovingAvg(100): 501.40
# Episode 476  | EpReward: 320.00 | MovingAvg(100): 500.20
# Episode 477  | EpReward: 1020.00 | MovingAvg(100): 505.00
# Episode 478  | EpReward: 580.00 | MovingAvg(100): 505.70
# Episode 479  | EpReward: 240.00 | MovingAvg(100): 501.20
# Episode 480  | EpReward: 360.00 | MovingAvg(100): 497.50
#
# --- DEBUG 471-480 ---
# Avg PolicyLoss: -0.0127 | Avg ValueLoss: 2.9295 | Avg Entropy: 1.7086 | Avg TotalLoss: 1.3667
# Advantage μ: -0.0000 | min: -1.6420 | max: 1.6111
# Action distribution (last 10 eps): 0:526 (9.8%), 1:225 (4.2%), 2:487 (9.1%), 3:197 (3.7%), 4:280 (5.2%), 5:2811 (52.6%), 6:196 (3.7%), 7:305 (5.7%), 8:322 (6.0%)
#
# Episode 481  | EpReward: 320.00 | MovingAvg(100): 497.40
# Episode 482  | EpReward: 260.00 | MovingAvg(100): 495.30
# Episode 483  | EpReward: 420.00 | MovingAvg(100): 496.30
# Episode 484  | EpReward: 330.00 | MovingAvg(100): 494.40
# Episode 485  | EpReward: 370.00 | MovingAvg(100): 494.30
# Episode 486  | EpReward: 430.00 | MovingAvg(100): 495.20
# Episode 487  | EpReward: 810.00 | MovingAvg(100): 500.10
# Episode 488  | EpReward: 670.00 | MovingAvg(100): 501.60
# Episode 489  | EpReward: 200.00 | MovingAvg(100): 496.10
# Episode 490  | EpReward: 580.00 | MovingAvg(100): 497.20
#
# --- DEBUG 481-490 ---
# Avg PolicyLoss: 0.0919 | Avg ValueLoss: 1.1367 | Avg Entropy: 1.9716 | Avg TotalLoss: 0.5617
# Advantage μ: 0.0000 | min: -1.6334 | max: 1.7295
# Action distribution (last 10 eps): 0:509 (9.8%), 1:252 (4.9%), 2:499 (9.6%), 3:223 (4.3%), 4:330 (6.4%), 5:2611 (50.3%), 6:181 (3.5%), 7:308 (5.9%), 8:281 (5.4%)
#
# Episode 491  | EpReward: 370.00 | MovingAvg(100): 495.70
# Episode 492  | EpReward: 740.00 | MovingAvg(100): 497.10
# Episode 493  | EpReward: 390.00 | MovingAvg(100): 498.70
# Episode 494  | EpReward: 490.00 | MovingAvg(100): 499.50
# Episode 495  | EpReward: 860.00 | MovingAvg(100): 504.70
# Episode 496  | EpReward: 520.00 | MovingAvg(100): 507.00
# Episode 497  | EpReward: 380.00 | MovingAvg(100): 507.80
# Episode 498  | EpReward: 310.00 | MovingAvg(100): 508.50
# Episode 499  | EpReward: 460.00 | MovingAvg(100): 506.70
# Episode 500  | EpReward: 300.00 | MovingAvg(100): 507.00
#
# --- DEBUG 491-500 ---
# Avg PolicyLoss: 0.0953 | Avg ValueLoss: 3.9871 | Avg Entropy: 1.4755 | Avg TotalLoss: 2.0151
# Advantage μ: 0.0003 | min: -1.4513 | max: 1.4126
# Action distribution (last 10 eps): 0:367 (7.1%), 1:164 (3.2%), 2:370 (7.2%), 3:152 (3.0%), 4:241 (4.7%), 5:3281 (63.7%), 6:130 (2.5%), 7:235 (4.6%), 8:209 (4.1%)
#
# Episode 501  | EpReward: 420.00 | MovingAvg(100): 507.30
# Episode 502  | EpReward: 560.00 | MovingAvg(100): 507.80
# Episode 503  | EpReward: 250.00 | MovingAvg(100): 506.40
# Episode 504  | EpReward: 480.00 | MovingAvg(100): 505.00
# Episode 505  | EpReward: 600.00 | MovingAvg(100): 501.90
# Episode 506  | EpReward: 220.00 | MovingAvg(100): 497.40
# Episode 507  | EpReward: 610.00 | MovingAvg(100): 498.40
# Episode 508  | EpReward: 990.00 | MovingAvg(100): 502.60
# Episode 509  | EpReward: 660.00 | MovingAvg(100): 504.10
# Episode 510  | EpReward: 820.00 | MovingAvg(100): 508.10
#
# --- DEBUG 501-510 ---
# Avg PolicyLoss: 0.1611 | Avg ValueLoss: 4.5922 | Avg Entropy: 1.6156 | Avg TotalLoss: 2.3764
# Advantage μ: 0.0001 | min: -1.5911 | max: 1.5524
# Action distribution (last 10 eps): 0:410 (8.1%), 1:175 (3.5%), 2:360 (7.1%), 3:178 (3.5%), 4:276 (5.4%), 5:3108 (61.3%), 6:150 (3.0%), 7:202 (4.0%), 8:210 (4.1%)
#
# Episode 511  | EpReward: 390.00 | MovingAvg(100): 506.70
# Episode 512  | EpReward: 580.00 | MovingAvg(100): 507.60
# Episode 513  | EpReward: 480.00 | MovingAvg(100): 510.00
# ...
# Episode 3240 | EpReward: 600.00 | MovingAvg(100): 539.80
#
# --- DEBUG 3231-3240 ---
# Avg PolicyLoss: 0.3773 | Avg ValueLoss: 0.6623 | Avg Entropy: 0.9254 | Avg TotalLoss: 0.6622
# Advantage μ: -0.0000 | min: -1.5971 | max: 1.2475
# Action distribution (last 10 eps): 0:226 (5.0%), 1:149 (3.3%), 2:134 (3.0%), 3:152 (3.4%), 4:227 (5.0%), 5:3051 (67.3%), 6:110 (2.4%), 7:377 (8.3%), 8:106 (2.3%)
#
# Episode 3241 | EpReward: 980.00 | MovingAvg(100): 545.00
# Episode 3242 | EpReward: 390.00 | MovingAvg(100): 545.60
# Episode 3243 | EpReward: 310.00 | MovingAvg(100): 543.30
# Episode 3244 | EpReward: 380.00 | MovingAvg(100): 541.30
# Episode 3245 | EpReward: 1290.00 | MovingAvg(100): 546.60
# Episode 3246 | EpReward: 570.00 | MovingAvg(100): 548.90
# Episode 3247 | EpReward: 570.00 | MovingAvg(100): 549.20
# Episode 3248 | EpReward: 580.00 | MovingAvg(100): 552.80
# Episode 3249 | EpReward: 1250.00 | MovingAvg(100): 559.90
# Episode 3250 | EpReward: 570.00 | MovingAvg(100): 560.80
#
# --- DEBUG 3241-3250 ---
# Avg PolicyLoss: 0.7073 | Avg ValueLoss: 11.2823 | Avg Entropy: 0.5930 | Avg TotalLoss: 6.3188
# Advantage μ: -0.0000 | min: -1.5145 | max: 1.4957
# Action distribution (last 10 eps): 0:245 (4.6%), 1:160 (3.0%), 2:214 (4.0%), 3:131 (2.5%), 4:214 (4.0%), 5:3737 (70.4%), 6:94 (1.8%), 7:349 (6.6%), 8:166 (3.1%)
#
# Episode 3251 | EpReward: 890.00 | MovingAvg(100): 566.90
# Episode 3252 | EpReward: 440.00 | MovingAvg(100): 565.40
# Episode 3253 | EpReward: 890.00 | MovingAvg(100): 569.00
# Episode 3254 | EpReward: 490.00 | MovingAvg(100): 569.00
# Episode 3255 | EpReward: 390.00 | MovingAvg(100): 558.40
# Episode 3256 | EpReward: 710.00 | MovingAvg(100): 561.80
# Episode 3257 | EpReward: 380.00 | MovingAvg(100): 561.60
# Episode 3258 | EpReward: 640.00 | MovingAvg(100): 561.40
# Episode 3259 | EpReward: 480.00 | MovingAvg(100): 561.10
# Episode 3260 | EpReward: 610.00 | MovingAvg(100): 561.10
#
# --- DEBUG 3251-3260 ---
# Avg PolicyLoss: -0.0247 | Avg ValueLoss: 3.6610 | Avg Entropy: 1.1622 | Avg TotalLoss: 1.7477
# Advantage μ: 0.0000 | min: -1.6120 | max: 1.4567
# Action distribution (last 10 eps): 0:387 (7.0%), 1:238 (4.3%), 2:273 (4.9%), 3:305 (5.5%), 4:288 (5.2%), 5:3232 (58.2%), 6:198 (3.6%), 7:416 (7.5%), 8:212 (3.8%)
#
# Episode 3261 | EpReward: 690.00 | MovingAvg(100): 565.50
# Episode 3262 | EpReward: 530.00 | MovingAvg(100): 560.80
# Episode 3263 | EpReward: 410.00 | MovingAvg(100): 557.00
# Episode 3264 | EpReward: 900.00 | MovingAvg(100): 561.80
# Episode 3265 | EpReward: 250.00 | MovingAvg(100): 557.00
# Episode 3266 | EpReward: 320.00 | MovingAvg(100): 557.00
# Episode 3267 | EpReward: 780.00 | MovingAvg(100): 559.70
# Episode 3268 | EpReward: 450.00 | MovingAvg(100): 560.50
# Episode 3269 | EpReward: 240.00 | MovingAvg(100): 558.10
# Episode 3270 | EpReward: 520.00 | MovingAvg(100): 556.90
#
# --- DEBUG 3261-3270 ---
# Avg PolicyLoss: 0.1299 | Avg ValueLoss: 8.9691 | Avg Entropy: 1.1056 | Avg TotalLoss: 4.5592
# Advantage μ: 0.0000 | min: -1.7925 | max: 1.4081
# Action distribution (last 10 eps): 0:305 (6.1%), 1:209 (4.1%), 2:218 (4.3%), 3:225 (4.5%), 4:255 (5.1%), 5:3148 (62.5%), 6:175 (3.5%), 7:319 (6.3%), 8:185 (3.7%)
#
# Episode 3271 | EpReward: 760.00 | MovingAvg(100): 558.10
# Episode 3272 | EpReward: 440.00 | MovingAvg(100): 559.40
# Episode 3273 | EpReward: 340.00 | MovingAvg(100): 555.10
# Episode 3274 | EpReward: 400.00 | MovingAvg(100): 551.60
# Episode 3275 | EpReward: 940.00 | MovingAvg(100): 555.50
# Episode 3276 | EpReward: 540.00 | MovingAvg(100): 556.30
# Episode 3277 | EpReward: 530.00 | MovingAvg(100): 556.50
# Episode 3278 | EpReward: 600.00 | MovingAvg(100): 558.20
# Episode 3279 | EpReward: 540.00 | MovingAvg(100): 559.80
# Episode 3280 | EpReward: 1300.00 | MovingAvg(100): 566.70
#
# --- DEBUG 3271-3280 ---
# Avg PolicyLoss: -0.0295 | Avg ValueLoss: 0.8738 | Avg Entropy: 1.9132 | Avg TotalLoss: 0.3118
# Advantage μ: -0.0000 | min: -1.9523 | max: 1.4592
# Action distribution (last 10 eps): 0:356 (6.4%), 1:229 (4.1%), 2:315 (5.7%), 3:269 (4.9%), 4:285 (5.2%), 5:3232 (58.5%), 6:217 (3.9%), 7:363 (6.6%), 8:263 (4.8%)
#
# Episode 3281 | EpReward: 530.00 | MovingAvg(100): 566.00
# Episode 3282 | EpReward: 560.00 | MovingAvg(100): 568.30
# Episode 3283 | EpReward: 600.00 | MovingAvg(100): 570.20
# Episode 3284 | EpReward: 550.00 | MovingAvg(100): 573.30
# Episode 3285 | EpReward: 450.00 | MovingAvg(100): 570.20
# Episode 3286 | EpReward: 640.00 | MovingAvg(100): 570.60
# Episode 3287 | EpReward: 570.00 | MovingAvg(100): 572.80
# Episode 3288 | EpReward: 630.00 | MovingAvg(100): 574.10
# Episode 3289 | EpReward: 1050.00 | MovingAvg(100): 579.80
# Episode 3290 | EpReward: 420.00 | MovingAvg(100): 580.10
#
# --- DEBUG 3281-3290 ---
# Avg PolicyLoss: 0.0166 | Avg ValueLoss: 41.7912 | Avg Entropy: 1.4102 | Avg TotalLoss: 20.8417
# Advantage μ: 0.0000 | min: -1.8834 | max: 1.4709
# Action distribution (last 10 eps): 0:364 (6.2%), 1:253 (4.3%), 2:415 (7.0%), 3:341 (5.8%), 4:290 (4.9%), 5:3322 (56.2%), 6:252 (4.3%), 7:389 (6.6%), 8:290 (4.9%)
#
# Episode 3291 | EpReward: 550.00 | MovingAvg(100): 580.30
# Episode 3292 | EpReward: 530.00 | MovingAvg(100): 578.30
# Episode 3293 | EpReward: 630.00 | MovingAvg(100): 576.10
# Episode 3294 | EpReward: 590.00 | MovingAvg(100): 578.90
# Episode 3295 | EpReward: 550.00 | MovingAvg(100): 578.50
# Episode 3296 | EpReward: 590.00 | MovingAvg(100): 562.90
# Episode 3297 | EpReward: 480.00 | MovingAvg(100): 562.50
# Episode 3298 | EpReward: 250.00 | MovingAvg(100): 552.20
# Episode 3299 | EpReward: 1300.00 | MovingAvg(100): 561.40
# Episode 3300 | EpReward: 430.00 | MovingAvg(100): 563.40
#
# --- DEBUG 3291-3300 ---
# Avg PolicyLoss: 0.3503 | Avg ValueLoss: 13.3041 | Avg Entropy: 0.7792 | Avg TotalLoss: 6.9634
# Advantage μ: -0.0000 | min: -1.8515 | max: 1.4564
# Action distribution (last 10 eps): 0:257 (5.1%), 1:167 (3.3%), 2:272 (5.4%), 3:198 (3.9%), 4:210 (4.1%), 5:3359 (66.1%), 6:169 (3.3%), 7:274 (5.4%), 8:173 (3.4%)
#
# Episode 3301 | EpReward: 340.00 | MovingAvg(100): 563.40
# Episode 3302 | EpReward: 1310.00 | MovingAvg(100): 573.70
# Episode 3303 | EpReward: 330.00 | MovingAvg(100): 567.20
# Episode 3304 | EpReward: 420.00 | MovingAvg(100): 564.30
# Episode 3305 | EpReward: 210.00 | MovingAvg(100): 561.40
# Episode 3306 | EpReward: 320.00 | MovingAvg(100): 562.10
# Episode 3307 | EpReward: 500.00 | MovingAvg(100): 563.50
# Episode 3308 | EpReward: 520.00 | MovingAvg(100): 561.20
# Episode 3309 | EpReward: 710.00 | MovingAvg(100): 564.90
# Episode 3310 | EpReward: 2280.00 | MovingAvg(100): 585.20
#
# --- DEBUG 3301-3310 ---
# Avg PolicyLoss: 0.0664 | Avg ValueLoss: 24.0459 | Avg Entropy: 1.1838 | Avg TotalLoss: 12.0302
# Advantage μ: 0.0000 | min: -1.8774 | max: 1.4815
# Action distribution (last 10 eps): 0:288 (4.9%), 1:213 (3.7%), 2:277 (4.8%), 3:195 (3.3%), 4:225 (3.9%), 5:3886 (66.7%), 6:166 (2.8%), 7:368 (6.3%), 8:211 (3.6%)
#
# Episode 3311 | EpReward: 280.00 | MovingAvg(100): 583.30
# Episode 3312 | EpReward: 1080.00 | MovingAvg(100): 582.10
# Episode 3313 | EpReward: 340.00 | MovingAvg(100): 572.30
# Episode 3314 | EpReward: 1560.00 | MovingAvg(100): 582.70
# Episode 3315 | EpReward: 520.00 | MovingAvg(100): 582.30
# Episode 3316 | EpReward: 440.00 | MovingAvg(100): 582.80
# Episode 3317 | EpReward: 600.00 | MovingAvg(100): 583.00
# Episode 3318 | EpReward: 520.00 | MovingAvg(100): 581.70
# Episode 3319 | EpReward: 360.00 | MovingAvg(100): 581.50
# Episode 3320 | EpReward: 580.00 | MovingAvg(100): 582.80
#
# --- DEBUG 3311-3320 ---
# Avg PolicyLoss: 0.0189 | Avg ValueLoss: 8.9029 | Avg Entropy: 1.3744 | Avg TotalLoss: 4.4016
# Advantage μ: -0.0000 | min: -1.7228 | max: 1.1758
# Action distribution (last 10 eps): 0:359 (6.3%), 1:177 (3.1%), 2:246 (4.3%), 3:193 (3.4%), 4:232 (4.0%), 5:3791 (66.0%), 6:169 (2.9%), 7:367 (6.4%), 8:208 (3.6%)
#
# Episode 3321 | EpReward: 520.00 | MovingAvg(100): 583.60
# Episode 3322 | EpReward: 340.00 | MovingAvg(100): 582.40
# Episode 3323 | EpReward: 750.00 | MovingAvg(100): 587.30
# Episode 3324 | EpReward: 520.00 | MovingAvg(100): 588.00
# Episode 3325 | EpReward: 640.00 | MovingAvg(100): 589.00
# Episode 3326 | EpReward: 880.00 | MovingAvg(100): 593.00
# Episode 3327 | EpReward: 410.00 | MovingAvg(100): 593.00
# Episode 3328 | EpReward: 530.00 | MovingAvg(100): 594.50
# Episode 3329 | EpReward: 390.00 | MovingAvg(100): 591.00
# Episode 3330 | EpReward: 720.00 | MovingAvg(100): 594.90
#
# --- DEBUG 3321-3330 ---
# Avg PolicyLoss: -12.3421 | Avg ValueLoss: 64.2371 | Avg Entropy: 1.1146 | Avg TotalLoss: 19.7207
# Advantage μ: 0.0000 | min: -1.7456 | max: 1.2193
# Action distribution (last 10 eps): 0:261 (4.9%), 1:189 (3.5%), 2:244 (4.6%), 3:218 (4.1%), 4:227 (4.3%), 5:3459 (64.8%), 6:187 (3.5%), 7:317 (5.9%), 8:233 (4.4%)
#
# Episode 3331 | EpReward: 480.00 | MovingAvg(100): 597.30
# Episode 3332 | EpReward: 520.00 | MovingAvg(100): 595.90
# Episode 3333 | EpReward: 510.00 | MovingAvg(100): 597.90
# Episode 3334 | EpReward: 330.00 | MovingAvg(100): 594.90
# Episode 3335 | EpReward: 750.00 | MovingAvg(100): 598.40
# Episode 3336 | EpReward: 350.00 | MovingAvg(100): 598.30
# Episode 3337 | EpReward: 480.00 | MovingAvg(100): 600.70
# Episode 3338 | EpReward: 710.00 | MovingAvg(100): 604.30
# Episode 3339 | EpReward: 280.00 | MovingAvg(100): 601.20
# Episode 3340 | EpReward: 240.00 | MovingAvg(100): 597.60
#
# --- DEBUG 3331-3340 ---
# Avg PolicyLoss: 0.4556 | Avg ValueLoss: 356.6700 | Avg Entropy: 0.9373 | Avg TotalLoss: 178.7438
# Advantage μ: 0.0000 | min: -1.6575 | max: 1.7152
# Action distribution (last 10 eps): 0:272 (6.1%), 1:210 (4.7%), 2:258 (5.8%), 3:181 (4.0%), 4:192 (4.3%), 5:2725 (60.8%), 6:139 (3.1%), 7:312 (7.0%), 8:194 (4.3%)
#
# Episode 3341 | EpReward: 520.00 | MovingAvg(100): 593.00
# Episode 3342 | EpReward: 1280.00 | MovingAvg(100): 601.90
# Episode 3343 | EpReward: 450.00 | MovingAvg(100): 603.30
# Episode 3344 | EpReward: 560.00 | MovingAvg(100): 605.10
# Episode 3345 | EpReward: 590.00 | MovingAvg(100): 598.10
# Episode 3346 | EpReward: 400.00 | MovingAvg(100): 596.40
# Episode 3347 | EpReward: 530.00 | MovingAvg(100): 596.00
# Episode 3348 | EpReward: 720.00 | MovingAvg(100): 597.40
# Episode 3349 | EpReward: 230.00 | MovingAvg(100): 587.20
# Episode 3350 | EpReward: 240.00 | MovingAvg(100): 583.90
#
# --- DEBUG 3341-3350 ---
# Avg PolicyLoss: -3.1832 | Avg ValueLoss: 87.4137 | Avg Entropy: 1.2881 | Avg TotalLoss: 40.4593
# Advantage μ: 0.0000 | min: -1.9670 | max: 1.5320
# Action distribution (last 10 eps): 0:332 (6.8%), 1:198 (4.1%), 2:194 (4.0%), 3:147 (3.0%), 4:200 (4.1%), 5:3249 (66.5%), 6:96 (2.0%), 7:321 (6.6%), 8:146 (3.0%)
#
# Episode 3351 | EpReward: 710.00 | MovingAvg(100): 582.10
# Episode 3352 | EpReward: 620.00 | MovingAvg(100): 583.90
# Episode 3353 | EpReward: 340.00 | MovingAvg(100): 578.40
# Episode 3354 | EpReward: 820.00 | MovingAvg(100): 581.70
# Episode 3355 | EpReward: 800.00 | MovingAvg(100): 585.80
# Episode 3356 | EpReward: 290.00 | MovingAvg(100): 581.60
# Episode 3357 | EpReward: 470.00 | MovingAvg(100): 582.50
# Episode 3358 | EpReward: 610.00 | MovingAvg(100): 582.20
# Episode 3359 | EpReward: 800.00 | MovingAvg(100): 585.40
# Episode 3360 | EpReward: 660.00 | MovingAvg(100): 585.90
#
# --- DEBUG 3351-3360 ---
# Avg PolicyLoss: 0.0229 | Avg ValueLoss: 0.9284 | Avg Entropy: 1.6424 | Avg TotalLoss: 0.4050
# Advantage μ: 0.0000 | min: -1.4036 | max: 1.6196
# Action distribution (last 10 eps): 0:432 (7.4%), 1:257 (4.4%), 2:316 (5.4%), 3:232 (4.0%), 4:246 (4.2%), 5:3476 (59.7%), 6:214 (3.7%), 7:412 (7.1%), 8:240 (4.1%)
#
# Episode 3361 | EpReward: 250.00 | MovingAvg(100): 581.50
# Episode 3362 | EpReward: 610.00 | MovingAvg(100): 582.30
# Episode 3363 | EpReward: 440.00 | MovingAvg(100): 582.60
# Episode 3364 | EpReward: 780.00 | MovingAvg(100): 581.40
# Episode 3365 | EpReward: 610.00 | MovingAvg(100): 585.00
# Episode 3366 | EpReward: 420.00 | MovingAvg(100): 586.00
# Episode 3367 | EpReward: 530.00 | MovingAvg(100): 583.50
# Episode 3368 | EpReward: 370.00 | MovingAvg(100): 582.70
# Episode 3369 | EpReward: 380.00 | MovingAvg(100): 584.10
# Episode 3370 | EpReward: 1030.00 | MovingAvg(100): 589.20
#
# --- DEBUG 3361-3370 ---
# Avg PolicyLoss: -0.2619 | Avg ValueLoss: 22.4855 | Avg Entropy: 1.6098 | Avg TotalLoss: 10.9003
# Advantage μ: 0.0000 | min: -1.3581 | max: 1.5078
# Action distribution (last 10 eps): 0:349 (6.4%), 1:243 (4.5%), 2:263 (4.8%), 3:221 (4.1%), 4:259 (4.8%), 5:3176 (58.4%), 6:186 (3.4%), 7:494 (9.1%), 8:252 (4.6%)
#
# Episode 3371 | EpReward: 710.00 | MovingAvg(100): 588.70
# Episode 3372 | EpReward: 490.00 | MovingAvg(100): 589.20
# Episode 3373 | EpReward: 400.00 | MovingAvg(100): 589.80
# Episode 3374 | EpReward: 310.00 | MovingAvg(100): 588.90
# Episode 3375 | EpReward: 450.00 | MovingAvg(100): 584.00
# Episode 3376 | EpReward: 340.00 | MovingAvg(100): 582.00
# Episode 3377 | EpReward: 400.00 | MovingAvg(100): 580.70
# Episode 3378 | EpReward: 530.00 | MovingAvg(100): 580.00
# Episode 3379 | EpReward: 510.00 | MovingAvg(100): 579.70
# Episode 3380 | EpReward: 420.00 | MovingAvg(100): 570.90
#
# --- DEBUG 3371-3380 ---
# Avg PolicyLoss: 0.0304 | Avg ValueLoss: 21.3715 | Avg Entropy: 1.3064 | Avg TotalLoss: 10.6508
# Advantage μ: 0.0000 | min: -1.4138 | max: 1.7528
# Action distribution (last 10 eps): 0:307 (6.3%), 1:172 (3.5%), 2:169 (3.4%), 3:148 (3.0%), 4:222 (4.5%), 5:3241 (66.0%), 6:141 (2.9%), 7:358 (7.3%), 8:152 (3.1%)
#
# Episode 3381 | EpReward: 1010.00 | MovingAvg(100): 575.70
# Episode 3382 | EpReward: 870.00 | MovingAvg(100): 578.80
# Episode 3383 | EpReward: 670.00 | MovingAvg(100): 579.50
# Episode 3384 | EpReward: 490.00 | MovingAvg(100): 578.90
# Episode 3385 | EpReward: 610.00 | MovingAvg(100): 580.50
# Episode 3386 | EpReward: 660.00 | MovingAvg(100): 580.70
# Episode 3387 | EpReward: 540.00 | MovingAvg(100): 580.40
# Episode 3388 | EpReward: 420.00 | MovingAvg(100): 578.30
# Episode 3389 | EpReward: 440.00 | MovingAvg(100): 572.20
# Episode 3390 | EpReward: 680.00 | MovingAvg(100): 574.80
#
# --- DEBUG 3381-3390 ---
# Avg PolicyLoss: -7.1689 | Avg ValueLoss: 74.7070 | Avg Entropy: 1.2125 | Avg TotalLoss: 30.1239
# Advantage μ: -0.0000 | min: -1.7585 | max: 1.8411
# Action distribution (last 10 eps): 0:281 (4.9%), 1:200 (3.5%), 2:229 (4.0%), 3:245 (4.2%), 4:244 (4.2%), 5:3721 (64.5%), 6:202 (3.5%), 7:410 (7.1%), 8:239 (4.1%)
#
# Episode 3391 | EpReward: 370.00 | MovingAvg(100): 573.00
# Episode 3392 | EpReward: 320.00 | MovingAvg(100): 570.90
# Episode 3393 | EpReward: 490.00 | MovingAvg(100): 569.50
# Episode 3394 | EpReward: 810.00 | MovingAvg(100): 571.70
# Episode 3395 | EpReward: 840.00 | MovingAvg(100): 574.60
# Episode 3396 | EpReward: 650.00 | MovingAvg(100): 575.20
# Episode 3397 | EpReward: 440.00 | MovingAvg(100): 574.80
# Episode 3398 | EpReward: 710.00 | MovingAvg(100): 579.40
# Episode 3399 | EpReward: 490.00 | MovingAvg(100): 571.30
# Episode 3400 | EpReward: 260.00 | MovingAvg(100): 569.60
#
# --- DEBUG 3391-3400 ---
# Avg PolicyLoss: 1.3680 | Avg ValueLoss: 109.9910 | Avg Entropy: 0.6941 | Avg TotalLoss: 56.3288
# Advantage μ: -0.0000 | min: -1.9145 | max: 1.5192
# Action distribution (last 10 eps): 0:197 (3.9%), 1:177 (3.5%), 2:166 (3.3%), 3:204 (4.1%), 4:202 (4.0%), 5:3499 (69.9%), 6:149 (3.0%), 7:237 (4.7%), 8:174 (3.5%)
#
# Episode 3401 | EpReward: 360.00 | MovingAvg(100): 569.80
# Episode 3402 | EpReward: 460.00 | MovingAvg(100): 561.30
# Episode 3403 | EpReward: 820.00 | MovingAvg(100): 566.20
# Episode 3404 | EpReward: 440.00 | MovingAvg(100): 566.40
# Episode 3405 | EpReward: 370.00 | MovingAvg(100): 568.00
# Episode 3406 | EpReward: 1860.00 | MovingAvg(100): 583.40
# Episode 3407 | EpReward: 330.00 | MovingAvg(100): 581.70
# Episode 3408 | EpReward: 340.00 | MovingAvg(100): 579.90
# Episode 3409 | EpReward: 460.00 | MovingAvg(100): 577.40
# Episode 3410 | EpReward: 1240.00 | MovingAvg(100): 567.00
#
# --- DEBUG 3401-3410 ---
# Avg PolicyLoss: 2.7802 | Avg ValueLoss: 2.9718 | Avg Entropy: 1.2380 | Avg TotalLoss: 4.2042
# Advantage μ: 0.0000 | min: -1.8899 | max: 1.6593
# Action distribution (last 10 eps): 0:287 (5.8%), 1:188 (3.8%), 2:200 (4.0%), 3:207 (4.2%), 4:237 (4.8%), 5:3075 (62.1%), 6:210 (4.2%), 7:306 (6.2%), 8:240 (4.8%)
#
# Episode 3411 | EpReward: 1000.00 | MovingAvg(100): 574.20
# Episode 3412 | EpReward: 500.00 | MovingAvg(100): 568.40
# Episode 3413 | EpReward: 470.00 | MovingAvg(100): 569.70
# Episode 3414 | EpReward: 360.00 | MovingAvg(100): 557.70
